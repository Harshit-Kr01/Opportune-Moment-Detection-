# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report
from scipy.stats import zscore
from sklearn.cluster import KMeans
from sklearn.preprocessing import RobustScaler
from sklearn.metrics.pairwise import rbf_kernel

import warnings
warnings.filterwarnings("ignore", message="KMeans is known to have a memory leak")

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import classification_report, roc_auc_score, precision_recall_curve, average_precision_score
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Activation, Dropout, Bidirectional, Multiply, Flatten, Lambda,RepeatVector, Permute 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from scipy.stats import zscore
from sklearn.metrics.pairwise import rbf_kernel
from scipy.signal import resample, butter, filtfilt, welch
from tensorflow.keras.losses import BinaryCrossentropy
from sklearn.cluster import KMeans

# %%
def load_physiological_data(file_path):
    columns = ["time", "ECG", "BVP", "GSR", "Resp", "Skin_Temp", "EMG_z", "EMG_c", "EMG_t"]
    df = pd.read_csv(file_path, sep="\t", names=columns)
    return df

# Load valence-arousal data
def load_valence_arousal_data(file_path):
    df = pd.read_csv(file_path, sep="\t", names=["jsttime", "valence", "arousal"])
    return df

# %%
def preprocess_data(physio_df, va_df, window_size=5):
    # Downsample
    physio_downsampled = physio_df.iloc[::1000].copy()
    va_downsampled = va_df.iloc[::20].copy()

    # Create window ID
    start_time = min(physio_downsampled["time"].min(), va_downsampled["jsttime"].min())
    physio_downsampled["window"] = ((physio_downsampled["time"] - start_time) // window_size).astype(int)
    va_downsampled["window"] = ((va_downsampled["jsttime"] - start_time) // window_size).astype(int)

    # Features to aggregate
    agg_dict = {
        "ECG": "mean",
        "BVP": ["mean", "std"],
        "GSR": ["mean", "std"],
        "Resp": "mean",
        "Skin_Temp": ["mean", "std"],
        "EMG_c": "mean",
        "EMG_t": "mean"
    }

    # Group by window
    physio_segmented = physio_downsampled.groupby("window").agg(agg_dict).reset_index()

    # Flatten column MultiIndex (e.g., ('BVP', 'mean') → 'BVP_mean')
    physio_segmented.columns = ["window"] + [f"{col}_{stat}" if stat else col for col, stat in physio_segmented.columns[1:]]

    # Rename columns to match model expectations
    physio_segmented = physio_segmented.rename(columns={
        "ECG_mean": "ECG",
        "BVP_mean": "BVP",
        "GSR_mean": "GSR",
        "Resp_mean": "Resp",
        "Skin_Temp_mean": "Skin_temp",
        "EMG_c_mean": "EMG_c",
        "EMG_t_mean": "EMG_t",
        "BVP_std": "BVP_std",
        "GSR_std": "GSR_std",
        "Skin_Temp_std": "Skin_temp_std"
    })

    # Compute slope for GSR (difference between successive means)
    physio_segmented["GSR_slope"] = physio_segmented["GSR"].diff().fillna(0)

    # Same for valence-arousal
    va_segmented = va_downsampled.groupby("window").mean().reset_index()

    return physio_segmented, va_segmented

# %%
def compute_rulsif_change_scores(X, alpha=0.1, sigma=0.1, lambda_param=1e-3):
    n = len(X) - 1
    change_scores = np.zeros(n)
    
    for i in range(n):
        X_t, X_t_next = X[i], X[i + 1]
        
        # Compute Gaussian Kernel Matrix
        K_t = rbf_kernel(X_t.reshape(-1, 1), X_t.reshape(-1, 1), gamma=1/(2*sigma**2))
        K_t_next = rbf_kernel(X_t_next.reshape(-1, 1), X_t_next.reshape(-1, 1), gamma=1/(2*sigma**2))
        
        # Compute Weights using Least Squares Importance Fitting (LSIF)
        H = alpha * K_t + (1 - alpha) * K_t_next + lambda_param * np.eye(K_t.shape[0])
        h = np.mean(K_t, axis=1)
        
        theta = np.linalg.solve(H, h)
        
        # Compute Change Score
        change_scores[i] = np.mean(np.square(K_t_next.dot(theta) - 1))
    
    return change_scores

# Identify significant changes and label opportune moments
def label_opportune_moments(change_scores):
    mean, std = np.mean(change_scores), np.std(change_scores)
    threshold = mean + 3 * std
    outliers = change_scores > threshold
    
    # Clustering the remaining scores
    valid_indices = np.where(~outliers)[0]  # Indices of non-outliers
    valid_scores = change_scores[valid_indices]
    
    if len(valid_scores) > 1:  # Ensure there are enough points for clustering
        kmeans = KMeans(n_clusters=2, random_state=42).fit(valid_scores.reshape(-1, 1))
        centroids = kmeans.cluster_centers_.flatten()
        high_cluster = np.argmax(centroids)
        high_values = (kmeans.labels_ == high_cluster) & (valid_scores > centroids[high_cluster])
        
        # Map high_values back to the original indices
        high_values_original = np.zeros_like(change_scores, dtype=bool)
        high_values_original[valid_indices] = high_values
    else:
        # If there are not enough valid scores, treat all as non-opportune
        high_values_original = np.zeros_like(change_scores, dtype=bool)
    
    # Mark opportune moments
    opportune_moments = np.where(outliers | high_values_original)[0]
    return opportune_moments

# %%
# Align valence-arousal data with physiological data windows
def align_data(physiological_data, valence_arousal_data, window_size=5):
    # Convert jsttime to window index
    start_time = physiological_data["time"].min()
    valence_arousal_data["window"] = ((valence_arousal_data["jsttime"] - start_time) // window_size).astype(int)
    
    # Merge data on window index
    merged_data = pd.merge(physiological_data, valence_arousal_data, on="window", how="inner")
    return merged_data

def scale_valence_arousal(df):
    df = df.copy()
    for dim in ["valence", "arousal"]:
        max_abs = np.max(np.abs(df[dim]))
        df[dim] = df[dim] / max_abs if max_abs != 0 else 0.0
    return df

# Map valence-arousal to emotion classes
def map_to_emotion_classes(valence, arousal):
    # Define emotion classes based on valence and arousal
    if valence >= 0 and arousal >= 0:
        return "Happy"
    elif valence >= 0 and arousal < 0:
        return "Relaxed"
    elif valence < 0 and arousal >= 0:
        return "Stressed"
    else:
        return "Sad"

# %%
import joblib
import os

def load_student_model(user_id, model_name="random_forest"):
    """
    Load a distilled classical student model (e.g., Random Forest, XGBoost, SVM) for a specific user.

    Args:
        user_id (str or int): Either 'User1' or just 1
        model_name (str): "random_forest", "xgboost", or "svm"

    Returns:
        Loaded model object (from joblib)
    """
    # Ensure user_id is formatted as 'UserX'
    if isinstance(user_id, int):
        user_id = f"User{user_id}"

    model_path = os.path.join("../dump/final_models/models_distilled", model_name, f"{user_id}.pkl")
    
    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model not found at: {model_path}")
    
    return joblib.load(model_path)

# %%
def elliott(x, p):
    return (p * x) / (1 + K.abs(x))

# Derivative of PEF
def elliott_derivative(x, p):
    return p / ((K.abs(x) + 1) ** 2)

# Swish Activation Function
def swish(x):
    return x * K.sigmoid(x)

# Custom PEF Activation Layer
class PEFLayer(Activation):
    def __init__(self, activation, **kwargs):
        super(PEFLayer, self).__init__(activation, **kwargs)
        self.p = K.variable(1.0)  # Initialize parameter p

    def call(self, inputs):
        return elliott(inputs, self.p)

# %%
from tensorflow.keras.models import load_model
import os

def load_student_model(user_id):
    if isinstance(user_id, int):
        user_id = f"User{user_id}"

    #model_path = os.path.join("../dump", "final_models", "saved_models_emotion_personalized", f"user_{user_id}", "student_model")
    model_path = os.path.join("../","saved_models_emotion_personalized", f"user_{user_id}", "student_model")

    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Model not found at: {model_path}")

    return load_model(
        model_path,
        custom_objects={
            'PEFLayer': PEFLayer,
            'elliott': elliott,
            'swish': swish
        },
        compile=False  # Optional if you don't need to retrain
    )

# %%
def train_and_evaluate_classifier(X_train, X_test, y_train, y_test):
    model = RandomForestClassifier(random_state=42)
    model.fit(X_train, y_train)
    
    # Predict on test set
    y_pred = model.predict(X_test)
    
    # Evaluate performance
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average="weighted")
    print(classification_report(y_test, y_pred, zero_division=0))

    print("Classification Report:")

    return accuracy, f1

# %% [markdown]
# # Load and Test Models

# %%
if __name__ == "__main__":
    results = []

    opportune_features = ['BVP', 'BVP_std', 'GSR', 'GSR_std', 'GSR_slope', 'Skin_temp', 'Skin_temp_std']
    model_features = ["ECG", "EMG_c", "EMG_t", "Resp", "Skin_temp"]
    change_score_features = ['BVP', 'GSR', 'Skin_temp']
    student_features = opportune_features
    threshold = 0.5

    for user_id in range(1, 31):
        try:
            physio_data = load_physiological_data(
                f"../case_dataset-master/case_dataset-master/data/raw/physiological/sub{user_id}_DAQ.txt")
            va_data = load_valence_arousal_data(
                f"../case_dataset-master/case_dataset-master/data/raw/annotations/sub{user_id}_joystick.txt")

            physio_segmented, va_segmented = preprocess_data(physio_data, va_data)
            va_segmented = scale_valence_arousal(va_segmented)
            merged_data = pd.merge(physio_segmented, va_segmented, on="window", how="inner")

            merged_data["emotion"] = merged_data.apply(
                lambda row: map_to_emotion_classes(row["valence"], row["arousal"]), axis=1)

            # Detect RuLSIF opportune moments
            X_opportune = merged_data[change_score_features].values
            change_scores = compute_rulsif_change_scores(X_opportune)
            opportune_moments = label_opportune_moments(change_scores)

            if len(opportune_moments) < 5:
                print(f"Too few opportune moments for User {user_id}. Skipping...")
                continue

            opportune_data = merged_data[merged_data["window"].isin(opportune_moments)]
            opportune_data = opportune_data.sort_values("window").reset_index(drop=True)

            # Split opportune_data for emotion classifier test
            opportune_train_data, opportune_test_data = train_test_split(
                opportune_data, test_size=0.2, random_state=42)

            inopportune_data = merged_data[~merged_data["window"].isin(opportune_moments)]

            # Combine opportune (80%) and inopportune data for detection model input
            detection_input_data = pd.concat([opportune_train_data, inopportune_data], ignore_index=True)
            detection_input_data = detection_input_data.sort_values("window").reset_index(drop=True)
            student_signal_data = detection_input_data[student_features].copy()

            from sklearn.preprocessing import RobustScaler

            # Compute RuLSIF change scores
            change_score_input = detection_input_data[change_score_features].values
            student_change_scores = compute_rulsif_change_scores(change_score_input)

            if len(student_change_scores) < len(student_signal_data):
                student_change_scores = np.append(student_change_scores, [0] * (len(student_signal_data) - len(student_change_scores)))
            elif len(student_change_scores) > len(student_signal_data):
                student_change_scores = student_change_scores[:len(student_signal_data)]
  # to match length

            # Add change score as a new feature
            student_signal_data["change_score"] = student_change_scores

            # Concatenate all features into a NumPy array
            student_input_array = student_signal_data.values  # shape: (n_samples, 8)

            # Apply RobustScaler on the whole array
            scaler = RobustScaler()
            student_input_scaled = scaler.fit_transform(student_input_array)  # shape: (n_samples, 8)

            # Convert to 3D for LSTM input
            student_input_3D = np.expand_dims(student_input_scaled, axis=1)  # shape: (n_samples, 1, 8)


            # Predict opportune moments with trained student model
            student_model = load_student_model(user_id)
            _, _, pred_probs = student_model.predict(student_input_3D, verbose=0)
            predicted_opportune_mask = (pred_probs.flatten() > 0.5)
            detected_opportune_data = detection_input_data[predicted_opportune_mask]

            if len(detected_opportune_data) < 5:
                print(f"Too few predicted opportune moments for User {user_id}. Skipping...")
                continue

            # Train emotion classifier on predicted opportune moments
            X_train_emotion = detected_opportune_data[model_features]
            y_train_emotion = detected_opportune_data["emotion"]
            X_test_emotion = opportune_test_data[model_features]
            y_test_emotion = opportune_test_data["emotion"]

            # Show test indices and class info for training
            print(f"User {user_id} — Test windows (opportune_test_data): {sorted(opportune_test_data['window'].tolist())}")
            print(f"User {user_id} — Emotion class distribution in train set:\n{y_train_emotion.value_counts().to_string()}\n")


            accuracy_opportune, f1_opportune = train_and_evaluate_classifier(
                X_train_emotion, X_test_emotion, y_train_emotion, y_test_emotion
            )

            results.append({
                "User ID": user_id,
                "Accuracy (Opportune)": accuracy_opportune,
                "F1 Score (Opportune)": f1_opportune,
                "Opportune Moments Count": len(opportune_moments)
            })

            print(f"Successfully processed User {user_id}\n\n")

        except FileNotFoundError:
            print(f"Data files for User {user_id} not found. Skipping...")
            continue
        except Exception as e:
            print(f"Unexpected error processing User {user_id}: {str(e)}. Skipping...")
            continue

    results_df = pd.DataFrame(results)
    results_df.to_csv("baselines/baseline_emotion_personalized.csv", index=False)
    print("\nFinal Results:")
    print(results_df)

# %% [markdown]
# # Personalized Model

# %%
""" This one is for personalized"""

from tensorflow.keras.models import load_model
import os

def load_student_model(user_id):
    model_path = os.path.join("../", "saved_models_emotion_personalized", f"user_User{user_id}", "student_model")

    if not os.path.exists(model_path):
        raise FileNotFoundError(f"Student model for User {user_id} not found at {model_path}")
    
    model = load_model(model_path, compile=False)
    return model



if __name__ == "__main__":
    results = []

    opportune_features = ['BVP', 'BVP_std', 'GSR', 'GSR_std', 'GSR_slope', 'Skin_temp', 'Skin_temp_std']
    model_features = ["ECG", "EMG_c", "EMG_t", "Resp", "Skin_temp"]
    change_score_features = ['BVP', 'GSR', 'Skin_temp']
    student_features = opportune_features
    threshold = 0.5

    for user_id in range(1, 31):
        try:
            physio_data = load_physiological_data(
                f"../case_dataset-master/case_dataset-master/data/raw/physiological/sub{user_id}_DAQ.txt")
            va_data = load_valence_arousal_data(
                f"../case_dataset-master/case_dataset-master/data/raw/annotations/sub{user_id}_joystick.txt")

            physio_segmented, va_segmented = preprocess_data(physio_data, va_data)
            va_segmented = scale_valence_arousal(va_segmented)
            merged_data = pd.merge(physio_segmented, va_segmented, on="window", how="inner")

            merged_data["emotion"] = merged_data.apply(
                lambda row: map_to_emotion_classes(row["valence"], row["arousal"]), axis=1)

            # Detect RuLSIF opportune moments
            X_opportune = merged_data[change_score_features].values
            change_scores = compute_rulsif_change_scores(X_opportune)
            opportune_moments = label_opportune_moments(change_scores)

            if len(opportune_moments) < 5:
                print(f"Too few opportune moments for User {user_id}. Skipping...")
                continue

            opportune_data = merged_data[merged_data["window"].isin(opportune_moments)]
            opportune_data = opportune_data.sort_values("window").reset_index(drop=True)

            # Split opportune_data for emotion classifier test
            opportune_train_data, opportune_test_data = train_test_split(
                opportune_data, test_size=0.2, random_state=42)

            inopportune_data = merged_data[~merged_data["window"].isin(opportune_moments)]

            # Combine opportune (80%) and inopportune data for detection model input
            detection_input_data = pd.concat([opportune_train_data, inopportune_data], ignore_index=True)
            detection_input_data = detection_input_data.sort_values("window").reset_index(drop=True)
            student_signal_data = detection_input_data[student_features].copy()

            from sklearn.preprocessing import RobustScaler

            # Compute RuLSIF change scores
            change_score_input = detection_input_data[change_score_features].values
            student_change_scores = compute_rulsif_change_scores(change_score_input)

            if len(student_change_scores) < len(student_signal_data):
                student_change_scores = np.append(student_change_scores, [0] * (len(student_signal_data) - len(student_change_scores)))
            elif len(student_change_scores) > len(student_signal_data):
                student_change_scores = student_change_scores[:len(student_signal_data)]
  # to match length

            # Add change score as a new feature
            student_signal_data["change_score"] = student_change_scores

            # Concatenate all features into a NumPy array
            student_input_array = student_signal_data.values  # shape: (n_samples, 8)

            # Apply RobustScaler on the whole array
            scaler = RobustScaler()
            student_input_scaled = scaler.fit_transform(student_input_array)  # shape: (n_samples, 8)

            # Convert to 3D for LSTM input
            student_input_3D = np.expand_dims(student_input_scaled, axis=1)  # shape: (n_samples, 1, 8)


            # Predict opportune moments with trained student model
            student_model = load_student_model(user_id)
            pred_probs = student_model.predict(student_input_3D, verbose=0)  # shape (n_samples, 1)
            predicted_opportune_mask = (pred_probs.flatten() > threshold)

            detected_opportune_data = detection_input_data[predicted_opportune_mask]

            if len(detected_opportune_data) < 5:
                print(f"Too few predicted opportune moments for User {user_id}. Skipping...")
                continue

            # Train emotion classifier on predicted opportune moments
            X_train_emotion = detected_opportune_data[model_features]
            y_train_emotion = detected_opportune_data["emotion"]
            X_test_emotion = opportune_test_data[model_features]
            y_test_emotion = opportune_test_data["emotion"]

            # Show test indices and class info for training
            print(f"User {user_id} — Test windows (opportune_test_data): {sorted(opportune_test_data['window'].tolist())}")
            print(f"User {user_id} — Emotion class distribution in train set:\n{y_train_emotion.value_counts().to_string()}\n")


            accuracy_opportune, f1_opportune = train_and_evaluate_classifier(
                X_train_emotion, X_test_emotion, y_train_emotion, y_test_emotion
            )

            results.append({
                "User ID": user_id,
                "Accuracy (Opportune)": accuracy_opportune,
                "F1 Score (Opportune)": f1_opportune,
                "Opportune Moments Count": len(opportune_moments)
            })

            print(f"Successfully processed User {user_id}\n\n")

        except FileNotFoundError as fnf_error:
            print(f"FileNotFoundError for User {user_id}: {fnf_error}. Skipping...")

        except Exception as e:
            print(f"Unexpected error processing User {user_id}: {str(e)}. Skipping...")
            continue

    results_df = pd.DataFrame(results)
    results_df.to_csv("baselines/baseline_emotion_personalized.csv", index=False)
    print("\nFinal Results:")
    print(results_df)
# Out:
# User 1 — Test windows (opportune_test_data): [60, 63, 66, 67, 69, 70, 75, 80, 81, 82, 89, 92, 93, 96, 106, 107, 111, 116, 129, 133, 141, 144, 159, 162, 164, 165, 166, 175, 188, 190, 192, 194, 197, 204, 213]
# User 1 — Emotion class distribution in train set:
# emotion
# Happy       42
# Stressed    12
# Relaxed      4
#
#               precision    recall  f1-score   support
#
#        Happy       0.71      1.00      0.83        24
#      Relaxed       0.00      0.00      0.00         4
#     Stressed       1.00      0.14      0.25         7
#
#     accuracy                           0.71        35
#    macro avg       0.57      0.38      0.36        35
# weighted avg       0.68      0.71      0.62        35
#
# Classification Report:
# Successfully processed User 1
#
#
# User 2 — Test windows (opportune_test_data): [44, 66, 72, 73, 111, 112, 173, 174, 178, 183, 189, 226, 229, 235, 238, 437, 438, 439, 452, 454, 457, 462, 475, 477, 488]
# User 2 — Emotion class distribution in train set:
# emotion
# Stressed    38
# Happy        8
# Relaxed      1
#
#               precision    recall  f1-score   support
#
#        Happy       1.00      0.14      0.25         7
#      Relaxed       0.00      0.00      0.00         3
#          Sad       0.00      0.00      0.00         1
#     Stressed       0.58      1.00      0.74        14
#
#     accuracy                           0.60        25
#    macro avg       0.40      0.29      0.25        25
# weighted avg       0.61      0.60      0.48        25
#
# Classification Report:
# Successfully processed User 2
#
#
# User 3 — Test windows (opportune_test_data): [5, 6, 9, 24, 26, 108, 111, 121, 124, 125, 135, 139, 152, 154, 156, 163, 178, 183, 195, 199, 203, 204, 225, 234, 239, 241, 244, 253, 254, 257, 258, 272, 279, 281, 285, 286, 298, 302, 307, 311, 325, 334, 341, 355, 387, 390, 394, 406, 416, 417, 419, 439, 441, 462, 466, 471, 476, 486]
# User 3 — Emotion class distribution in train set:
# emotion
# Happy       43
# Stressed    16
# Relaxed     10
#
#               precision    recall  f1-score   support
#
#        Happy       0.66      0.94      0.78        33
#      Relaxed       1.00      0.30      0.46        10
#          Sad       0.00      0.00      0.00         5
#     Stressed       0.75      0.60      0.67        10
#
#     accuracy                           0.69        58
#    macro avg       0.60      0.46      0.48        58
# weighted avg       0.68      0.69      0.64        58
#
# Classification Report:
# Successfully processed User 3
#
#
# Too few predicted opportune moments for User 4. Skipping...
# User 5 — Test windows (opportune_test_data): [87, 90, 99, 103, 115, 117, 118, 123, 135, 138, 139, 153, 159, 161, 166, 168, 209, 214, 216, 269, 273, 278, 280, 284, 290, 291, 292, 297, 304, 307, 311, 322, 323, 330, 344, 347, 350, 360, 362, 365, 367, 374, 375, 377, 380, 419, 422, 424, 425, 430, 442, 464, 474, 478, 479]
# User 5 — Emotion class distribution in train set:
# emotion
# Happy       7
# Stressed    1
# Sad         1
#
#               precision    recall  f1-score   support
#
#        Happy       0.69      1.00      0.81        37
#      Relaxed       0.00      0.00      0.00         3
#          Sad       0.00      0.00      0.00         1
#     Stressed       0.00      0.00      0.00        14
#
#     accuracy                           0.67        55
#    macro avg       0.17      0.25      0.20        55
# weighted avg       0.46      0.67      0.55        55
#
# Classification Report:
# Successfully processed User 5
#
#
# User 6 — Test windows (opportune_test_data): [0, 4, 396, 399, 405, 409, 417, 418, 420, 426, 431, 434, 443, 460, 463, 466, 467, 470, 473, 480]
# User 6 — Emotion class distribution in train set:
# emotion
# Happy       129
# Relaxed      50
# Sad          10
# Stressed      1
#
#               precision    recall  f1-score   support
#
#        Happy       0.81      1.00      0.90        13
#      Relaxed       1.00      0.57      0.73         7
#
#     accuracy                           0.85        20
#    macro avg       0.91      0.79      0.81        20
# weighted avg       0.88      0.85      0.84        20
#
# Classification Report:
# Successfully processed User 6
#
#
# FileNotFoundError for User 7: Student model for User 7 not found at ../saved_models_emotion_personalized\user_User7\student_model. Skipping...
# Too few predicted opportune moments for User 8. Skipping...
# Too few predicted opportune moments for User 9. Skipping...
# Too few predicted opportune moments for User 10. Skipping...
# User 11 — Test windows (opportune_test_data): [9, 11, 12, 18, 19, 22, 26, 29, 30, 31, 117, 132, 136, 145, 147, 148, 150, 157, 162, 163, 312, 416, 417, 431, 438, 439, 448, 449, 456, 464]
# User 11 — Emotion class distribution in train set:
# emotion
# Happy       36
# Stressed     9
# Relaxed      7
# Sad          7
#
#               precision    recall  f1-score   support
#
#        Happy       0.83      0.95      0.89        21
#      Relaxed       1.00      0.29      0.44         7
#          Sad       0.25      0.50      0.33         2
#
#     accuracy                           0.77        30
#    macro avg       0.69      0.58      0.56        30
# weighted avg       0.83      0.77      0.75        30
#
# Classification Report:
# Successfully processed User 11
#
#
# Too few predicted opportune moments for User 12. Skipping...
# User 13 — Test windows (opportune_test_data): [0, 4, 10, 12, 20, 401, 438, 440, 445, 452, 459, 460, 471, 473, 477, 483, 487]
# User 13 — Emotion class distribution in train set:
# emotion
# Stressed    12
# Happy        3
#
#               precision    recall  f1-score   support
#
#        Happy       1.00      0.20      0.33        10
#      Relaxed       0.00      0.00      0.00         2
#     Stressed       0.33      1.00      0.50         5
#
#     accuracy                           0.41        17
#    macro avg       0.44      0.40      0.28        17
# weighted avg       0.69      0.41      0.34        17
#
# Classification Report:
# Successfully processed User 13
#
#
# User 14 — Test windows (opportune_test_data): [4, 10, 12, 16, 18, 19, 30, 31, 39, 59, 63, 78, 80, 89, 102, 107, 121, 135, 136, 160, 162, 169, 175, 176, 201, 222, 229]
# User 14 — Emotion class distribution in train set:
# emotion
# Happy       11
# Stressed     5
#
#               precision    recall  f1-score   support
#
#        Happy       0.81      0.74      0.77        23
#      Relaxed       0.00      0.00      0.00         3
#     Stressed       0.00      0.00      0.00         1
#
#     accuracy                           0.63        27
#    macro avg       0.27      0.25      0.26        27
# weighted avg       0.69      0.63      0.66        27
#
# Classification Report:
# Successfully processed User 14
#
#
# User 15 — Test windows (opportune_test_data): [4, 10, 11, 18, 19, 26, 27, 31, 36, 40, 45, 191, 192, 200, 205, 222, 223, 226, 235, 237, 239, 242, 247, 259, 266, 277]
# User 15 — Emotion class distribution in train set:
# emotion
# Happy       34
# Stressed    10
# Relaxed      4
#
#               precision    recall  f1-score   support
#
#        Happy       0.84      0.84      0.84        19
#      Relaxed       0.50      0.50      0.50         2
#     Stressed       0.60      0.60      0.60         5
#
#     accuracy                           0.77        26
#    macro avg       0.65      0.65      0.65        26
# weighted avg       0.77      0.77      0.77        26
#
# Classification Report:
# Successfully processed User 15
#
#
# User 16 — Test windows (opportune_test_data): [4, 44, 46, 287, 292, 295, 386, 398, 407, 409, 420, 423, 429, 435]
# User 16 — Emotion class distribution in train set:
# emotion
# Happy       14
# Stressed     8
# Relaxed      2
#
#               precision    recall  f1-score   support
#
#        Happy       0.90      1.00      0.95         9
#      Relaxed       0.00      0.00      0.00         1
#     Stressed       1.00      1.00      1.00         4
#
#     accuracy                           0.93        14
#    macro avg       0.63      0.67      0.65        14
# weighted avg       0.86      0.93      0.89        14
#
# Classification Report:
# Successfully processed User 16
#
#
# Too few predicted opportune moments for User 17. Skipping...
# User 18 — Test windows (opportune_test_data): [0, 111, 144, 145, 146, 168, 202, 208, 315, 318, 333, 385, 398, 400, 407, 408, 410, 411, 412, 434, 460, 481]
# User 18 — Emotion class distribution in train set:
# emotion
# Happy       40
# Relaxed     19
# Stressed    11
# Sad          1
#
#               precision    recall  f1-score   support
#
#        Happy       0.89      0.94      0.91        17
#      Relaxed       0.33      0.33      0.33         3
#     Stressed       1.00      0.50      0.67         2
#
#     accuracy                           0.82        22
#    macro avg       0.74      0.59      0.64        22
# weighted avg       0.82      0.82      0.81        22
#
# Classification Report:
# Successfully processed User 18
#
#
# Too few predicted opportune moments for User 19. Skipping...
# User 20 — Test windows (opportune_test_data): [9, 12, 15, 16, 18, 19, 24, 29, 99, 100, 136, 137, 140, 157, 162, 168, 169, 173, 189, 197, 275, 277, 280, 281, 287, 291, 314, 323, 368, 439, 445, 451, 461, 468, 470, 473]
# User 20 — Emotion class distribution in train set:
# emotion
# Happy       13
# Stressed     7
# Sad          3
#
#               precision    recall  f1-score   support
#
#        Happy       0.58      0.75      0.65        20
#      Relaxed       0.00      0.00      0.00         9
#          Sad       0.00      0.00      0.00         3
#     Stressed       0.20      0.50      0.29         4
#
#     accuracy                           0.47        36
#    macro avg       0.19      0.31      0.23        36
# weighted avg       0.34      0.47      0.39        36
#
# Classification Report:
# Successfully processed User 20
#
#
# User 21 — Test windows (opportune_test_data): [81, 186, 224, 226, 294, 304, 310, 315, 322, 326, 329, 331, 335, 348, 356, 360, 362, 367, 371, 392, 393, 414, 429, 434, 476]
# User 21 — Emotion class distribution in train set:
# emotion
# Happy       90
# Stressed    31
# Sad         23
# Relaxed     10
#
#               precision    recall  f1-score   support
#
#        Happy       0.80      0.89      0.84        18
#      Relaxed       0.00      0.00      0.00         2
#          Sad       0.33      0.50      0.40         2
#     Stressed       0.00      0.00      0.00         3
#
#     accuracy                           0.68        25
#    macro avg       0.28      0.35      0.31        25
# weighted avg       0.60      0.68      0.64        25
#
# Classification Report:
# Successfully processed User 21
#
#
# User 22 — Test windows (opportune_test_data): [203, 211, 221, 222, 223, 229, 241, 247, 253, 256, 267, 275, 398, 400, 402, 408, 409, 410, 411, 414, 426, 488]
# User 22 — Emotion class distribution in train set:
# emotion
# Happy    5
#
#               precision    recall  f1-score   support
#
#        Happy       0.86      1.00      0.93        19
#          Sad       0.00      0.00      0.00         1
#     Stressed       0.00      0.00      0.00         2
#
#     accuracy                           0.86        22
#    macro avg       0.29      0.33      0.31        22
# weighted avg       0.75      0.86      0.80        22
#
# Classification Report:
# Successfully processed User 22
#
#
# User 23 — Test windows (opportune_test_data): [0, 5, 9, 12, 16, 38, 44, 61, 65, 74, 310, 456, 460]
# User 23 — Emotion class distribution in train set:
# emotion
# Stressed    18
# Happy       17
# Sad         12
# Relaxed      8
#
#               precision    recall  f1-score   support
#
#        Happy       0.67      1.00      0.80         4
#      Relaxed       1.00      0.50      0.67         4
#          Sad       1.00      1.00      1.00         2
#     Stressed       1.00      1.00      1.00         3
#
#     accuracy                           0.85        13
#    macro avg       0.92      0.88      0.87        13
# weighted avg       0.90      0.85      0.84        13
#
# Classification Report:
# Successfully processed User 23
#
#
# User 24 — Test windows (opportune_test_data): [9, 12, 18, 19, 26, 29, 30, 31, 36, 45, 55, 56, 64, 68, 69, 73, 76, 78, 82, 104, 108, 110, 118, 197, 198, 201, 202, 211, 213, 215]
# User 24 — Emotion class distribution in train set:
# emotion
# Happy       41
# Stressed     3
# Relaxed      1
#
#               precision    recall  f1-score   support
#
#        Happy       0.93      0.96      0.95        27
#     Stressed       0.50      0.33      0.40         3
#
#     accuracy                           0.90        30
#    macro avg       0.71      0.65      0.67        30
# weighted avg       0.89      0.90      0.89        30
#
# Classification Report:
# Successfully processed User 24
#
#
# Too few predicted opportune moments for User 25. Skipping...
# User 26 — Test windows (opportune_test_data): [103, 104, 107, 120, 122, 123, 128, 131, 146, 149, 150, 167, 172, 173, 188, 194, 199, 201, 211, 212, 234, 236, 242, 247, 255, 263, 266, 267, 271, 275, 278, 287, 290, 293, 298, 300, 302, 305, 309, 316, 320, 325, 327, 334, 339, 341, 345, 349, 351, 359, 361, 368, 374, 384, 385, 396, 420, 426, 429]
# User 26 — Emotion class distribution in train set:
# emotion
# Stressed    9
# Happy       9
# Relaxed     1
# Sad         1
#
#               precision    recall  f1-score   support
#
#        Happy       0.62      0.56      0.59        36
#      Relaxed       0.00      0.00      0.00         5
#          Sad       0.00      0.00      0.00         9
#     Stressed       0.30      0.89      0.44         9
#
#     accuracy                           0.47        59
#    macro avg       0.23      0.36      0.26        59
# weighted avg       0.43      0.47      0.43        59
#
# Classification Report:
# Successfully processed User 26
#
#
# User 27 — Test windows (opportune_test_data): [9, 15, 16, 18, 30, 45, 55, 56, 60, 65, 66, 67, 68, 69, 75, 76, 78, 79, 82, 84, 93, 95, 104, 115, 124, 125, 128, 132, 147, 149, 161, 163, 165, 171, 177, 178, 184, 188, 191, 196, 201]
# User 27 — Emotion class distribution in train set:
# emotion
# Relaxed     7
# Stressed    7
# Happy       3
#
#               precision    recall  f1-score   support
#
#        Happy       0.64      0.44      0.52        16
#      Relaxed       0.53      0.77      0.62        13
#          Sad       0.00      0.00      0.00         3
#     Stressed       0.64      0.78      0.70         9
#
#     accuracy                           0.59        41
#    macro avg       0.45      0.50      0.46        41
# weighted avg       0.55      0.59      0.55        41
#
# Classification Report:
# Successfully processed User 27
#
#
# User 28 — Test windows (opportune_test_data): [243, 272, 283, 332, 375, 441, 444, 445, 448, 459, 461, 471]
# User 28 — Emotion class distribution in train set:
# emotion
# Happy       87
# Sad         18
# Stressed     8
# Relaxed      6
#
#               precision    recall  f1-score   support
#
#        Happy       0.82      1.00      0.90         9
#      Relaxed       0.00      0.00      0.00         1
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.00      0.00      0.00         1
#
#     accuracy                           0.83        12
#    macro avg       0.45      0.50      0.47        12
# weighted avg       0.70      0.83      0.76        12
#
# Classification Report:
# Successfully processed User 28
#
#
# User 29 — Test windows (opportune_test_data): [9, 15, 16, 18, 25, 30, 45, 55, 66, 67, 73, 75, 79, 93, 96, 98, 104, 108, 111, 112, 117, 118, 338, 342, 349, 352, 353, 356, 361, 370, 431, 433, 444, 448, 449, 454, 456, 458, 462, 464, 471, 473, 479, 487]
# User 29 — Emotion class distribution in train set:
# emotion
# Happy       34
# Stressed    27
# Relaxed      2
#
#               precision    recall  f1-score   support
#
#        Happy       0.95      0.90      0.92        39
#      Relaxed       0.00      0.00      0.00         2
#     Stressed       0.43      1.00      0.60         3
#
#     accuracy                           0.86        44
#    macro avg       0.46      0.63      0.51        44
# weighted avg       0.87      0.86      0.86        44
#
# Classification Report:
# Successfully processed User 29
#
#
# User 30 — Test windows (opportune_test_data): [40, 44, 45, 50, 53, 54, 59, 60, 65, 69, 81, 82, 103, 104, 111, 113, 118, 126, 138, 160, 162, 164, 166, 169, 170, 176, 193, 194, 243, 278, 287, 288, 310, 311, 315, 316, 323, 329, 333, 336, 337, 347, 350, 353, 357, 358, 371, 374, 381, 383, 389, 391, 393]
# User 30 — Emotion class distribution in train set:
# emotion
# Happy       27
# Relaxed      3
# Stressed     1
#
#               precision    recall  f1-score   support
#
#        Happy       0.62      0.94      0.75        32
#      Relaxed       0.75      0.33      0.46         9
#          Sad       0.00      0.00      0.00         2
#     Stressed       0.00      0.00      0.00        10
#
#     accuracy                           0.62        53
#    macro avg       0.34      0.32      0.30        53
# weighted avg       0.50      0.62      0.53        53
#
# Classification Report:
# Successfully processed User 30
#
#
#
# Final Results:
#     User ID  Accuracy (Opportune)  F1 Score (Opportune)  \
# 0         1              0.714286              0.617488
# 1         2              0.600000              0.482632
# 2         3              0.689655              0.635466
# 3         5              0.672727              0.547053
# 4         6              0.850000              0.837304
# 5        11              0.766667              0.748148
# 6        13              0.411765              0.343137
# 7        14              0.629630              0.658249
# 8        15              0.769231              0.769231
# 9        16              0.928571              0.894737
# 10       18              0.818182              0.812554
# 11       20              0.472222              0.394065
# 12       21              0.680000              0.638316
# 13       22              0.863636              0.800443
# 14       23              0.846154              0.835897
# 15       24              0.900000              0.890909
# 16       26              0.474576              0.426720
# 17       27              0.585366              0.554178
# 18       28              0.833333              0.758333
# 19       29              0.863636              0.857297
# 20       30              0.622642              0.531205
#
#     Opportune Moments Count
# 0                       173
# 1                       125
# 2                       289
# 3                       275
# 4                       100
# 5                       147
# 6                        85
# 7                       135
# 8                       130
# 9                        69
# 10                      108
# 11                      176
# 12                      121
# 13                      110
# 14                       65
# 15                      150
# 16                      295
# 17                      201
# 18                       57
# 19                      216
# 20                      264

# %% [markdown]
# # Fixed Time Based

# %%
if __name__ == "__main__":
    os.makedirs("baselines", exist_ok=True)
    results = []

    opportune_features = ['BVP', 'BVP_std', 'GSR', 'GSR_std', 'GSR_slope', 'Skin_temp', 'Skin_temp_std']
    change_score_features = ['BVP', 'GSR', 'Skin_temp']
    model_features = ["ECG", "EMG_c", "EMG_t", "Resp", "Skin_temp"]
    threshold = 0.5

    for user_id in range(1, 31):
        try:
            physio_data = load_physiological_data(
                f"../case_dataset-master/case_dataset-master/data/raw/physiological/sub{user_id}_DAQ.txt")
            va_data = load_valence_arousal_data(
                f"../case_dataset-master/case_dataset-master/data/raw/annotations/sub{user_id}_joystick.txt")

            physio_segmented, va_segmented = preprocess_data(physio_data, va_data)
            va_segmented = scale_valence_arousal(va_segmented)

            # Sort to ensure reproducibility
            physio_segmented = physio_segmented.sort_values("window").reset_index(drop=True)
            va_segmented = va_segmented.sort_values("window").reset_index(drop=True)

            merged_data = pd.merge(physio_segmented, va_segmented, on="window", how="inner")
            merged_data["emotion"] = merged_data.apply(
                lambda row: map_to_emotion_classes(row["valence"], row["arousal"]), axis=1
            )

            # Detect true opportune moments using RuLSIF
            X_opportune = merged_data[change_score_features].apply(zscore).values
            change_scores = compute_rulsif_change_scores(X_opportune)
            opportune_moments = label_opportune_moments(change_scores)

            if len(opportune_moments) < 5:
                print(f"Too few opportune moments for User {user_id}. Skipping...")
                continue

            opportune_data = merged_data[merged_data["window"].isin(opportune_moments)].copy()
            opportune_data = opportune_data.sort_values("window").reset_index(drop=True)

            # Train/test split from real RuLSIF opportune moments
            # Split 80% opportune train and 20% opportune test
            opportune_train_data, opportune_test_data = train_test_split(
                opportune_data, test_size=0.2, random_state=42)

            # Print test window segment IDs
            test_windows = sorted(opportune_test_data["window"].tolist())
            print(f"User {user_id} - Test segment windows: {test_windows}")

            # Identify inopportune segments
            inopportune_data = merged_data[~merged_data["window"].isin(opportune_moments)].copy()

            # Concatenate 80% opportune + inopportune segments for training
            combined_train_data = pd.concat([opportune_train_data, inopportune_data], ignore_index=True)

            X_train_emotion = combined_train_data[model_features]
            y_train_emotion = combined_train_data["emotion"]

            X_test_emotion = opportune_test_data[model_features]
            y_test_emotion = opportune_test_data["emotion"]

            
            scaler_class = RobustScaler()
            X_train_emotion_scaled = scaler_class.fit_transform(X_train_emotion)
            X_test_emotion_scaled = scaler_class.transform(X_test_emotion)

            accuracy, f1 = train_and_evaluate_classifier(
                X_train_emotion_scaled, X_test_emotion_scaled, y_train_emotion, y_test_emotion
            )

            results.append({
                "User ID": user_id,
                "Accuracy": accuracy,
                "F1 Score": f1,
                "Train Samples": len(X_train_emotion),
                "Test Samples": len(X_test_emotion)
            })

            print(f"Successfully processed User {user_id}")

        except FileNotFoundError:
            print(f"Data files for User {user_id} not found. Skipping...")
            continue
        except Exception as e:
            print(f"Unexpected error processing User {user_id}: {str(e)}. Skipping...")
            continue

    results_df = pd.DataFrame(results)
    results_df[["Accuracy", "F1 Score"]] = results_df[["Accuracy", "F1 Score"]].round(4)
    results_df.to_csv("baselines/baseline_emotion_fixed_time.csv", index=False)

    print("\nSaved results to baselines/baseline_emotion_fixed_time.csv")
# Out:
# User 1 - Test segment windows: [25, 33, 34, 39, 43, 46, 58, 59, 65, 89, 94, 95, 116, 122, 124, 133, 136, 142, 147, 149, 155, 169, 173, 193, 201, 211, 217, 249, 251, 261, 265, 272, 280, 287, 308, 324, 358, 375, 385, 391, 392, 394, 403, 411, 423, 427, 430, 435, 449, 450, 452, 454, 456, 471, 478, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.82      0.93      0.87        40
#      Relaxed       0.33      0.17      0.22         6
#          Sad       0.00      0.00      0.00         2
#     Stressed       0.75      0.75      0.75         8
#
#     accuracy                           0.79        56
#    macro avg       0.48      0.46      0.46        56
# weighted avg       0.73      0.79      0.75        56
#
# Classification Report:
# Successfully processed User 1
# User 2 - Test segment windows: [19, 23, 24, 31, 32, 37, 43, 52, 55, 72, 74, 100, 108, 109, 116, 118, 128, 135, 149, 168, 181, 191, 192, 197, 200, 201, 202, 207, 211, 241, 243, 247, 259, 269, 316, 362, 366, 391, 405, 406, 415, 428, 432, 433, 437, 438, 439, 457, 458, 468, 469, 480, 482, 483]
#               precision    recall  f1-score   support
#
#        Happy       1.00      0.95      0.97        38
#      Relaxed       0.80      1.00      0.89         4
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.92      1.00      0.96        11
#
#     accuracy                           0.96        54
#    macro avg       0.93      0.99      0.95        54
# weighted avg       0.97      0.96      0.96        54
#
# Classification Report:
# Successfully processed User 2
# User 3 - Test segment windows: [5, 9, 20, 25, 28, 29, 34, 37, 46, 49, 50, 60, 63, 65, 68, 84, 85, 88, 91, 97, 103, 106, 163, 164, 183, 187, 190, 203, 205, 208, 232, 247, 248, 256, 273, 290, 302, 309, 324, 346, 363, 367, 380, 381, 393, 398, 411, 418, 441, 444, 456, 457, 459, 465, 467, 471, 478, 486, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.81      0.89      0.85        38
#      Relaxed       0.75      0.64      0.69        14
#          Sad       0.00      0.00      0.00         2
#     Stressed       0.80      0.80      0.80         5
#
#     accuracy                           0.80        59
#    macro avg       0.59      0.58      0.59        59
# weighted avg       0.77      0.80      0.78        59
#
# Classification Report:
# Successfully processed User 3
# User 4 - Test segment windows: [11, 35, 38, 63, 64, 68, 70, 82, 83, 90, 97, 105, 120, 141, 148, 149, 150, 174, 181, 214, 222, 235, 237, 241, 243, 253, 255, 267, 284, 288, 289, 303, 330, 378, 381, 384, 393, 396, 399, 403, 404, 412, 422, 425, 431, 439, 444, 445, 452, 466, 476]
#               precision    recall  f1-score   support
#
#        Happy       0.77      1.00      0.87        30
#      Relaxed       0.67      0.67      0.67         3
#          Sad       1.00      0.50      0.67         2
#     Stressed       1.00      0.50      0.67        16
#
#     accuracy                           0.80        51
#    macro avg       0.86      0.67      0.72        51
# weighted avg       0.84      0.80      0.79        51
#
# Classification Report:
# Successfully processed User 4
# User 5 - Test segment windows: [5, 6, 9, 31, 33, 48, 56, 66, 71, 72, 86, 91, 95, 113, 117, 119, 122, 128, 141, 142, 170, 177, 188, 211, 246, 250, 251, 263, 280, 288, 306, 310, 318, 331, 347, 352, 360, 363, 365, 370, 374, 376, 381, 384, 386, 395, 408, 411, 424, 437, 445, 461, 463, 464, 465, 472, 475, 483]
#               precision    recall  f1-score   support
#
#        Happy       0.73      0.97      0.83        31
#      Relaxed       0.78      0.54      0.64        13
#          Sad       0.00      0.00      0.00         6
#     Stressed       0.88      0.88      0.88         8
#
#     accuracy                           0.76        58
#    macro avg       0.60      0.60      0.59        58
# weighted avg       0.69      0.76      0.71        58
#
# Classification Report:
# Successfully processed User 5
# User 6 - Test segment windows: [10, 13, 14, 19, 20, 23, 31, 37, 41, 56, 57, 77, 84, 88, 102, 106, 117, 132, 157, 186, 197, 208, 210, 211, 212, 213, 214, 221, 223, 247, 249, 251, 256, 263, 290, 315, 320, 333, 344, 347, 360, 367, 369, 370, 390, 391, 392, 410, 412, 425, 426, 449, 459, 460]
#               precision    recall  f1-score   support
#
#        Happy       0.85      0.97      0.91        35
#      Relaxed       1.00      0.54      0.70        13
#          Sad       0.75      1.00      0.86         3
#     Stressed       1.00      1.00      1.00         3
#
#     accuracy                           0.87        54
#    macro avg       0.90      0.88      0.87        54
# weighted avg       0.89      0.87      0.86        54
#
# Classification Report:
# Successfully processed User 6
# User 7 - Test segment windows: [7, 8, 13, 33, 36, 37, 63, 66, 79, 83, 86, 100, 103, 104, 120, 124, 129, 131, 139, 140, 162, 167, 188, 194, 208, 224, 233, 234, 242, 254, 257, 270, 276, 282, 290, 292, 294, 299, 304, 317, 334, 345, 347, 354, 365, 367, 378, 385, 387, 411, 413, 423, 434, 452, 453, 465, 470, 473, 477]
#               precision    recall  f1-score   support
#
#        Happy       0.84      0.95      0.89        44
#      Relaxed       0.67      0.40      0.50        10
#          Sad       0.00      0.00      0.00         1
#     Stressed       0.67      0.50      0.57         4
#
#     accuracy                           0.81        59
#    macro avg       0.54      0.46      0.49        59
# weighted avg       0.78      0.81      0.79        59
#
# Classification Report:
# Successfully processed User 7
# User 8 - Test segment windows: [6, 9, 10, 32, 36, 39, 40, 52, 53, 60, 63, 70, 77, 135, 144, 147, 156, 162, 177, 201, 205, 222, 225, 226, 229, 233, 242, 243, 259, 274, 277, 280, 341, 346, 351, 359, 379, 391, 399, 417, 419, 448, 454, 456, 470, 475, 482, 484, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.92      0.92      0.92        26
#      Relaxed       0.91      0.83      0.87        12
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.91      1.00      0.95        10
#
#     accuracy                           0.92        49
#    macro avg       0.94      0.94      0.94        49
# weighted avg       0.92      0.92      0.92        49
#
# Classification Report:
# Successfully processed User 8
# User 9 - Test segment windows: [5, 6, 12, 29, 33, 34, 41, 45, 59, 62, 63, 77, 83, 84, 100, 108, 117, 122, 137, 138, 144, 187, 189, 198, 205, 216, 232, 235, 236, 241, 245, 250, 289, 295, 302, 315, 318, 323, 330, 334, 349, 353, 358, 360, 370, 376, 379, 387, 392, 394, 409, 411, 419, 428, 450, 451, 463, 467, 474, 477]
#               precision    recall  f1-score   support
#
#        Happy       0.77      0.90      0.83        30
#      Relaxed       0.85      0.77      0.81        22
#     Stressed       0.80      0.50      0.62         8
#
#     accuracy                           0.80        60
#    macro avg       0.81      0.72      0.75        60
# weighted avg       0.80      0.80      0.79        60
#
# Classification Report:
# Successfully processed User 9
# User 10 - Test segment windows: [8, 11, 12, 19, 20, 31, 39, 50, 53, 71, 72, 108, 116, 117, 127, 129, 168, 174, 194, 202, 213, 221, 222, 223, 224, 225, 231, 238, 239, 264, 267, 272, 280, 296, 311, 357, 372, 385, 393, 394, 409, 414, 417, 418, 426, 429, 430, 451, 452, 467, 468, 478, 480, 481]
#               precision    recall  f1-score   support
#
#        Happy       0.90      0.95      0.93        39
#      Relaxed       0.86      0.86      0.86         7
#          Sad       0.50      1.00      0.67         1
#     Stressed       0.75      0.43      0.55         7
#
#     accuracy                           0.87        54
#    macro avg       0.75      0.81      0.75        54
# weighted avg       0.87      0.87      0.86        54
#
# Classification Report:
# Successfully processed User 10
# User 11 - Test segment windows: [9, 16, 25, 29, 32, 34, 35, 43, 71, 79, 80, 103, 116, 117, 128, 130, 133, 143, 146, 160, 165, 169, 175, 176, 180, 184, 185, 197, 199, 246, 271, 275, 298, 304, 312, 334, 340, 342, 372, 374, 391, 406, 407, 414, 419, 424, 426, 427, 433, 453, 457, 464, 466, 484, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.83      0.92      0.88        38
#      Relaxed       0.58      0.64      0.61        11
#          Sad       0.00      0.00      0.00         4
#     Stressed       0.00      0.00      0.00         2
#
#     accuracy                           0.76        55
#    macro avg       0.35      0.39      0.37        55
# weighted avg       0.69      0.76      0.73        55
#
# Classification Report:
# Successfully processed User 11
# User 12 - Test segment windows: [8, 9, 14, 43, 45, 54, 59, 77, 83, 84, 103, 107, 110, 126, 128, 130, 138, 147, 161, 165, 179, 182, 184, 185, 186, 194, 220, 227, 228, 231, 232, 233, 244, 246, 249, 268, 278, 304, 317, 321, 332, 379, 389, 392, 405, 407, 411, 412, 422, 429, 435, 436, 452, 453, 454, 465, 467, 468]
#               precision    recall  f1-score   support
#
#        Happy       0.89      0.98      0.93        43
#      Relaxed       0.67      0.50      0.57         4
#     Stressed       1.00      0.73      0.84        11
#
#     accuracy                           0.90        58
#    macro avg       0.85      0.73      0.78        58
# weighted avg       0.90      0.90      0.89        58
#
# Classification Report:
# Successfully processed User 12
# User 13 - Test segment windows: [20, 42, 43, 65, 67, 71, 72, 81, 82, 91, 97, 108, 123, 157, 164, 165, 166, 189, 195, 209, 214, 229, 231, 237, 239, 248, 251, 259, 270, 272, 273, 280, 316, 320, 337, 356, 389, 392, 399, 403, 404, 407, 419, 423, 429, 437, 442, 444, 455, 466, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.79      1.00      0.88        33
#      Relaxed       1.00      0.22      0.36         9
#          Sad       0.00      0.00      0.00         1
#     Stressed       1.00      0.88      0.93         8
#
#     accuracy                           0.82        51
#    macro avg       0.70      0.52      0.54        51
# weighted avg       0.84      0.82      0.78        51
#
# Classification Report:
# Successfully processed User 13
# User 14 - Test segment windows: [6, 19, 22, 32, 36, 45, 47, 49, 61, 82, 86, 87, 108, 118, 120, 130, 132, 138, 141, 143, 152, 162, 166, 185, 192, 199, 200, 223, 225, 249, 259, 267, 281, 288, 301, 314, 326, 363, 365, 369, 375, 378, 381, 385, 399, 404, 416, 420, 421, 431, 444, 453, 456, 458, 481, 482]
#               precision    recall  f1-score   support
#
#        Happy       0.85      0.97      0.91        40
#      Relaxed       0.75      0.67      0.71         9
#          Sad       1.00      0.50      0.67         2
#     Stressed       1.00      0.20      0.33         5
#
#     accuracy                           0.84        56
#    macro avg       0.90      0.59      0.65        56
# weighted avg       0.85      0.84      0.81        56
#
# Classification Report:
# Successfully processed User 14
# User 15 - Test segment windows: [5, 8, 10, 13, 21, 28, 30, 39, 57, 61, 62, 78, 81, 85, 98, 105, 106, 107, 113, 121, 123, 138, 144, 149, 153, 163, 168, 169, 183, 210, 214, 225, 236, 241, 267, 281, 291, 308, 309, 311, 312, 321, 332, 351, 353, 357, 373, 378, 385, 388, 406, 410, 414, 438, 439, 449, 453, 454, 456, 461, 476, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.62      0.97      0.76        36
#      Relaxed       1.00      0.07      0.13        14
#          Sad       1.00      0.14      0.25         7
#     Stressed       0.75      0.60      0.67         5
#
#     accuracy                           0.65        62
#    macro avg       0.84      0.45      0.45        62
# weighted avg       0.76      0.65      0.55        62
#
# Classification Report:
# Successfully processed User 15
# User 16 - Test segment windows: [6, 9, 10, 15, 19, 22, 26, 27, 36, 53, 57, 58, 75, 83, 85, 94, 98, 103, 114, 116, 180, 190, 193, 204, 209, 215, 216, 223, 234, 245, 246, 247, 258, 273, 277, 278, 286, 292, 306, 323, 357, 364, 366, 367, 373, 377, 390, 411, 414, 417, 420, 422, 455, 461, 472, 474]
#               precision    recall  f1-score   support
#
#        Happy       0.87      0.98      0.92        42
#      Relaxed       0.67      0.33      0.44         6
#          Sad       1.00      0.75      0.86         4
#     Stressed       1.00      0.75      0.86         4
#
#     accuracy                           0.88        56
#    macro avg       0.88      0.70      0.77        56
# weighted avg       0.87      0.88      0.86        56
#
# Classification Report:
# Successfully processed User 16
# User 17 - Test segment windows: [28, 34, 46, 50, 58, 60, 61, 68, 82, 86, 87, 104, 113, 115, 126, 129, 134, 141, 145, 185, 190, 197, 200, 252, 264, 265, 266, 275, 284, 289, 296, 318, 319, 334, 372, 377, 383, 396, 400, 403, 405, 415, 416, 418, 421, 435, 439, 441, 442, 448, 462, 465, 473, 477, 478]
#               precision    recall  f1-score   support
#
#        Happy       0.77      1.00      0.87        27
#      Relaxed       0.88      0.70      0.78        10
#          Sad       1.00      0.57      0.73         7
#     Stressed       1.00      0.73      0.84        11
#
#     accuracy                           0.84        55
#    macro avg       0.91      0.75      0.80        55
# weighted avg       0.87      0.84      0.83        55
#
# Classification Report:
# Successfully processed User 17
# User 18 - Test segment windows: [6, 9, 16, 22, 27, 29, 30, 37, 53, 57, 59, 86, 112, 117, 131, 133, 138, 144, 147, 184, 189, 213, 218, 225, 234, 235, 240, 245, 253, 257, 262, 276, 277, 284, 305, 315, 319, 341, 344, 351, 354, 368, 369, 372, 377, 396, 400, 404, 405, 411, 429, 443, 465, 474, 477]
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.96      0.91        45
#      Relaxed       0.40      0.29      0.33         7
#     Stressed       0.00      0.00      0.00         3
#
#     accuracy                           0.82        55
#    macro avg       0.42      0.41      0.41        55
# weighted avg       0.75      0.82      0.78        55
#
# Classification Report:
# Successfully processed User 18
# User 19 - Test segment windows: [12, 15, 16, 25, 26, 28, 29, 39, 40, 53, 56, 61, 71, 88, 97, 98, 99, 116, 120, 135, 144, 155, 158, 163, 165, 186, 187, 194, 202, 206, 207, 213, 223, 226, 230, 236, 247, 273, 284, 350, 351, 363, 373, 376, 383, 398, 405, 407, 417, 432, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.91      0.98      0.94        41
#      Relaxed       0.00      0.00      0.00         2
#     Stressed       0.86      0.75      0.80         8
#
#     accuracy                           0.90        51
#    macro avg       0.59      0.58      0.58        51
# weighted avg       0.87      0.90      0.88        51
#
# Classification Report:
# Successfully processed User 19
# User 20 - Test segment windows: [7, 11, 13, 25, 29, 32, 36, 38, 53, 84, 89, 99, 127, 136, 138, 149, 155, 162, 170, 176, 186, 196, 200, 215, 235, 248, 249, 282, 284, 293, 296, 301, 306, 311, 316, 321, 326, 341, 342, 347, 356, 359, 362, 368, 398, 414, 425, 427, 429, 435, 456, 463, 466, 468, 484, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.98      0.91        43
#      Relaxed       1.00      0.22      0.36         9
#          Sad       0.00      0.00      0.00         0
#     Stressed       0.75      0.75      0.75         4
#
#     accuracy                           0.84        56
#    macro avg       0.65      0.49      0.51        56
# weighted avg       0.87      0.84      0.81        56
#
# Classification Report:
# Successfully processed User 20
# User 21 - Test segment windows: [7, 9, 12, 25, 27, 34, 37, 51, 55, 56, 72, 78, 84, 86, 96, 98, 101, 111, 122, 131, 133, 134, 170, 171, 193, 195, 217, 221, 229, 241, 248, 249, 259, 261, 271, 274, 321, 350, 358, 367, 368, 371, 381, 382, 391, 398, 416, 418, 426, 430, 436, 446, 455, 456, 457, 468, 470]
#               precision    recall  f1-score   support
#
#        Happy       0.85      0.89      0.87        37
#      Relaxed       1.00      0.75      0.86         4
#          Sad       1.00      0.75      0.86         4
#     Stressed       0.67      0.67      0.67        12
#
#     accuracy                           0.82        57
#    macro avg       0.88      0.76      0.81        57
# weighted avg       0.83      0.82      0.82        57
#
# Classification Report:
# Successfully processed User 21
# User 22 - Test segment windows: [6, 9, 10, 15, 18, 19, 58, 60, 67, 75, 98, 106, 134, 157, 162, 164, 171, 190, 191, 198, 218, 221, 223, 225, 231, 240, 249, 259, 262, 263, 266, 301, 302, 323, 324, 329, 335, 339, 340, 342, 352, 356, 363, 381, 386, 392, 407, 413, 423, 451, 457, 479, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.73      0.97      0.83        33
#      Relaxed       0.83      0.38      0.53        13
#          Sad       0.00      0.00      0.00         2
#     Stressed       1.00      0.60      0.75         5
#
#     accuracy                           0.75        53
#    macro avg       0.64      0.49      0.53        53
# weighted avg       0.75      0.75      0.72        53
#
# Classification Report:
# Successfully processed User 22
# User 23 - Test segment windows: [12, 18, 19, 21, 22, 29, 34, 53, 72, 83, 93, 103, 105, 120, 123, 136, 148, 167, 183, 186, 198, 199, 210, 211, 212, 245, 269, 270, 275, 294, 298, 302, 333, 336, 345, 356, 361, 364, 377, 410, 412, 414, 416, 421, 460, 463, 474]
#               precision    recall  f1-score   support
#
#        Happy       0.82      0.96      0.89        28
#      Relaxed       1.00      0.62      0.77         8
#          Sad       1.00      0.57      0.73         7
#     Stressed       0.80      1.00      0.89         4
#
#     accuracy                           0.85        47
#    macro avg       0.90      0.79      0.82        47
# weighted avg       0.87      0.85      0.84        47
#
# Classification Report:
# Successfully processed User 23
# User 24 - Test segment windows: [10, 13, 14, 23, 24, 26, 27, 35, 36, 41, 44, 56, 79, 80, 81, 89, 94, 102, 117, 118, 143, 150, 154, 194, 207, 245, 257, 292, 295, 313, 314, 322, 323, 332, 333, 342, 353, 358, 360, 368, 441, 442, 445, 452, 456, 457, 464, 469, 473, 478, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.95      1.00      0.97        37
#      Relaxed       1.00      1.00      1.00         2
#          Sad       1.00      1.00      1.00         2
#     Stressed       1.00      0.80      0.89        10
#
#     accuracy                           0.96        51
#    macro avg       0.99      0.95      0.97        51
# weighted avg       0.96      0.96      0.96        51
#
# Classification Report:
# Successfully processed User 24
# User 25 - Test segment windows: [7, 10, 16, 20, 23, 25, 26, 35, 38, 51, 54, 55, 69, 77, 78, 79, 90, 94, 100, 104, 107, 108, 113, 132, 137, 140, 146, 147, 156, 160, 163, 168, 175, 185, 197, 206, 232, 240, 274, 275, 286, 289, 366, 372, 407, 415, 418, 442, 446, 448, 449, 453, 463, 472]
#               precision    recall  f1-score   support
#
#        Happy       0.76      0.94      0.84        31
#      Relaxed       0.50      0.38      0.43         8
#          Sad       1.00      0.43      0.60         7
#     Stressed       0.71      0.62      0.67         8
#
#     accuracy                           0.74        54
#    macro avg       0.74      0.59      0.63        54
# weighted avg       0.75      0.74      0.72        54
#
# Classification Report:
# Successfully processed User 25
# User 26 - Test segment windows: [14, 17, 24, 28, 31, 33, 34, 39, 64, 67, 68, 88, 94, 96, 102, 106, 111, 122, 124, 173, 175, 180, 182, 183, 196, 197, 198, 207, 215, 224, 237, 261, 263, 283, 308, 312, 333, 339, 343, 351, 357, 374, 388, 392, 393, 394, 395, 411, 454, 460, 463, 465, 466, 470, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.78      0.91      0.84        34
#      Relaxed       0.75      0.43      0.55         7
#          Sad       0.50      0.67      0.57         3
#     Stressed       0.86      0.55      0.67        11
#
#     accuracy                           0.76        55
#    macro avg       0.72      0.64      0.66        55
# weighted avg       0.77      0.76      0.75        55
#
# Classification Report:
# Successfully processed User 26
# User 27 - Test segment windows: [6, 9, 17, 21, 24, 28, 29, 34, 58, 63, 64, 94, 102, 104, 118, 120, 124, 129, 131, 153, 157, 167, 172, 176, 182, 183, 184, 189, 201, 210, 216, 246, 247, 255, 285, 317, 322, 360, 362, 365, 367, 381, 382, 385, 394, 413, 416, 418, 420, 426, 451, 468, 474, 478, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.97      0.97      0.97        32
#      Relaxed       0.85      1.00      0.92        11
#          Sad       0.00      0.00      0.00         2
#     Stressed       1.00      1.00      1.00        10
#
#     accuracy                           0.95        55
#    macro avg       0.70      0.74      0.72        55
# weighted avg       0.91      0.95      0.93        55
#
# Classification Report:
# Successfully processed User 27
# User 28 - Test segment windows: [9, 15, 16, 26, 31, 34, 38, 39, 50, 62, 65, 66, 83, 91, 101, 107, 109, 118, 130, 133, 144, 155, 159, 183, 187, 204, 207, 250, 256, 270, 274, 279, 294, 296, 316, 321, 335, 350, 359, 363, 364, 366, 377, 401, 425, 428, 431, 437, 461, 462, 466, 468, 470, 481, 484, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.87      0.95      0.91        43
#      Relaxed       0.00      0.00      0.00         4
#          Sad       0.86      0.75      0.80         8
#     Stressed       0.50      1.00      0.67         1
#
#     accuracy                           0.86        56
#    macro avg       0.56      0.68      0.59        56
# weighted avg       0.80      0.86      0.83        56
#
# Classification Report:
# Successfully processed User 28
# User 29 - Test segment windows: [6, 16, 17, 22, 27, 28, 37, 38, 46, 55, 73, 74, 139, 141, 144, 164, 166, 169, 170, 180, 184, 206, 208, 211, 212, 217, 244, 247, 248, 254, 261, 276, 288, 315, 341, 359, 368, 369, 370, 385, 387, 390, 396, 398, 428, 433, 437, 448, 463, 465, 466, 471, 488]
#               precision    recall  f1-score   support
#
#        Happy       0.89      0.95      0.92        42
#      Relaxed       1.00      0.33      0.50         3
#     Stressed       0.71      0.62      0.67         8
#
#     accuracy                           0.87        53
#    macro avg       0.87      0.64      0.70        53
# weighted avg       0.87      0.87      0.86        53
#
# Classification Report:
# Successfully processed User 29
# User 30 - Test segment windows: [7, 12, 23, 31, 37, 40, 41, 47, 62, 69, 70, 89, 102, 104, 115, 117, 123, 130, 133, 199, 204, 214, 217, 221, 230, 231, 232, 241, 250, 253, 259, 279, 280, 319, 347, 356, 360, 373, 375, 380, 384, 395, 396, 399, 417, 436, 439, 441, 442, 449, 464, 467, 473, 477, 478]
#               precision    recall  f1-score   support
#
#        Happy       0.87      0.94      0.90        35
#      Relaxed       0.71      0.71      0.71         7
#          Sad       1.00      0.50      0.67         2
#     Stressed       0.78      0.64      0.70        11
#
#     accuracy                           0.84        55
#    macro avg       0.84      0.70      0.75        55
# weighted avg       0.84      0.84      0.83        55
#
# Classification Report:
# Successfully processed User 30
#
# Saved results to baselines/baseline_emotion_fixed_time.csv

# %% [markdown]
# # Random Time Based

# %%
if __name__ == "__main__":
    import random
    os.makedirs("baselines", exist_ok=True)
    results = []

    opportune_features = ['BVP', 'BVP_std', 'GSR', 'GSR_std', 'GSR_slope', 'Skin_temp', 'Skin_temp_std']
    change_score_features = ['BVP', 'GSR', 'Skin_temp']
    model_features = ["ECG", "EMG_c", "EMG_t", "Resp", "Skin_temp"]
    threshold = 0.5

    for user_id in range(1, 31):
        try:
            physio_data = load_physiological_data(
                f"../case_dataset-master/case_dataset-master/data/raw/physiological/sub{user_id}_DAQ.txt")
            va_data = load_valence_arousal_data(
                f"../case_dataset-master/case_dataset-master/data/raw/annotations/sub{user_id}_joystick.txt")

            physio_segmented, va_segmented = preprocess_data(physio_data, va_data)
            va_segmented = scale_valence_arousal(va_segmented)

            # Sort to ensure reproducibility
            physio_segmented = physio_segmented.sort_values("window").reset_index(drop=True)
            va_segmented = va_segmented.sort_values("window").reset_index(drop=True)

            merged_data = pd.merge(physio_segmented, va_segmented, on="window", how="inner")
            merged_data["emotion"] = merged_data.apply(
                lambda row: map_to_emotion_classes(row["valence"], row["arousal"]), axis=1
            )

            # RuLSIF-based opportune detection
            X_opportune = merged_data[change_score_features].apply(zscore).values
            change_scores = compute_rulsif_change_scores(X_opportune)
            opportune_moments = label_opportune_moments(change_scores)

            if len(opportune_moments) < 5:
                print(f"Too few opportune moments for User {user_id}. Skipping...")
                continue

            opportune_data = merged_data[merged_data["window"].isin(opportune_moments)].copy()
            opportune_data = opportune_data.sort_values("window").reset_index(drop=True)

            # Train/test split from opportune moments
            opportune_train_data, opportune_test_data = train_test_split(
                opportune_data, test_size=0.2, random_state=42
            )

            # Print test segment window IDs
            test_windows = sorted(opportune_test_data["window"].tolist())
            print(f"User {user_id} - Test segment windows: {test_windows}")

            # Merge opportune train + all inopportune segments
            inopportune_data = merged_data[~merged_data["window"].isin(opportune_moments)].copy()
            combined_train_data = pd.concat([opportune_train_data, inopportune_data], ignore_index=True)

            # Apply 50% random sampling on combined train set
            sampled_train_data = combined_train_data.sample(frac=0.5, random_state=42).reset_index(drop=True)

            # Prepare features/labels
            X_train_emotion = sampled_train_data[model_features]
            y_train_emotion = sampled_train_data["emotion"]

            X_test_emotion = opportune_test_data[model_features]
            y_test_emotion = opportune_test_data["emotion"]

            # Apply RobustScaler
            scaler = RobustScaler()
            X_train_emotion_scaled = scaler.fit_transform(X_train_emotion)
            X_test_emotion_scaled = scaler.transform(X_test_emotion)

            # Train & Evaluate
            accuracy, f1 = train_and_evaluate_classifier(
                X_train_emotion_scaled, X_test_emotion_scaled, y_train_emotion, y_test_emotion
            )

            results.append({
                "User ID": user_id,
                "Accuracy": accuracy,
                "F1 Score": f1,
                "Train Samples": len(X_train_emotion),
                "Test Samples": len(X_test_emotion)
            })

            print(f"Successfully processed User {user_id}")

        except FileNotFoundError:
            print(f"Data files for User {user_id} not found. Skipping...")
            continue
        except Exception as e:
            print(f"Unexpected error processing User {user_id}: {str(e)}. Skipping...")
            continue

    # Save results
    results_df = pd.DataFrame(results)
    results_df[["Accuracy", "F1 Score"]] = results_df[["Accuracy", "F1 Score"]].round(4)
    results_df.to_csv("baselines/baseline_emotion_random_time.csv", index=False)

    print("\nSaved results to baselines/baseline_emotion_50percent_combined_train.csv")
# Out:
# User 1 - Test segment windows: [25, 33, 34, 39, 43, 46, 58, 59, 65, 89, 94, 95, 116, 122, 124, 133, 136, 142, 147, 149, 155, 169, 173, 193, 201, 211, 217, 249, 251, 261, 265, 272, 280, 287, 308, 324, 358, 375, 385, 391, 392, 394, 403, 411, 423, 427, 430, 435, 449, 450, 452, 454, 456, 471, 478, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.75      0.90      0.82        40
#      Relaxed       0.50      0.17      0.25         6
#          Sad       0.00      0.00      0.00         2
#     Stressed       0.50      0.38      0.43         8
#
#     accuracy                           0.71        56
#    macro avg       0.44      0.36      0.37        56
# weighted avg       0.66      0.71      0.67        56
#
# Classification Report:
# Successfully processed User 1
# User 2 - Test segment windows: [19, 23, 24, 31, 32, 37, 43, 52, 55, 72, 74, 100, 108, 109, 116, 118, 128, 135, 149, 168, 181, 191, 192, 197, 200, 201, 202, 207, 211, 241, 243, 247, 259, 269, 316, 362, 366, 391, 405, 406, 415, 428, 432, 433, 437, 438, 439, 457, 458, 468, 469, 480, 482, 483]
#               precision    recall  f1-score   support
#
#        Happy       1.00      0.87      0.93        38
#      Relaxed       0.57      1.00      0.73         4
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.85      1.00      0.92        11
#
#     accuracy                           0.91        54
#    macro avg       0.85      0.97      0.89        54
# weighted avg       0.94      0.91      0.91        54
#
# Classification Report:
# Successfully processed User 2
# User 3 - Test segment windows: [5, 9, 20, 25, 28, 29, 34, 37, 46, 49, 50, 60, 63, 65, 68, 84, 85, 88, 91, 97, 103, 106, 163, 164, 183, 187, 190, 203, 205, 208, 232, 247, 248, 256, 273, 290, 302, 309, 324, 346, 363, 367, 380, 381, 393, 398, 411, 418, 441, 444, 456, 457, 459, 465, 467, 471, 478, 486, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.81      0.92      0.86        38
#      Relaxed       0.73      0.57      0.64        14
#          Sad       0.00      0.00      0.00         2
#     Stressed       0.80      0.80      0.80         5
#
#     accuracy                           0.80        59
#    macro avg       0.59      0.57      0.58        59
# weighted avg       0.76      0.80      0.78        59
#
# Classification Report:
# Successfully processed User 3
# User 4 - Test segment windows: [11, 35, 38, 63, 64, 68, 70, 82, 83, 90, 97, 105, 120, 141, 148, 149, 150, 174, 181, 214, 222, 235, 237, 241, 243, 253, 255, 267, 284, 288, 289, 303, 330, 378, 381, 384, 393, 396, 399, 403, 404, 412, 422, 425, 431, 439, 444, 445, 452, 466, 476]
#               precision    recall  f1-score   support
#
#        Happy       0.75      1.00      0.86        30
#      Relaxed       0.33      0.33      0.33         3
#          Sad       1.00      0.50      0.67         2
#     Stressed       1.00      0.44      0.61        16
#
#     accuracy                           0.76        51
#    macro avg       0.77      0.57      0.62        51
# weighted avg       0.81      0.76      0.74        51
#
# Classification Report:
# Successfully processed User 4
# User 5 - Test segment windows: [5, 6, 9, 31, 33, 48, 56, 66, 71, 72, 86, 91, 95, 113, 117, 119, 122, 128, 141, 142, 170, 177, 188, 211, 246, 250, 251, 263, 280, 288, 306, 310, 318, 331, 347, 352, 360, 363, 365, 370, 374, 376, 381, 384, 386, 395, 408, 411, 424, 437, 445, 461, 463, 464, 465, 472, 475, 483]
#               precision    recall  f1-score   support
#
#        Happy       0.70      0.97      0.81        31
#      Relaxed       0.71      0.38      0.50        13
#          Sad       0.00      0.00      0.00         6
#     Stressed       0.88      0.88      0.88         8
#
#     accuracy                           0.72        58
#    macro avg       0.57      0.56      0.55        58
# weighted avg       0.65      0.72      0.67        58
#
# Classification Report:
# Successfully processed User 5
# User 6 - Test segment windows: [10, 13, 14, 19, 20, 23, 31, 37, 41, 56, 57, 77, 84, 88, 102, 106, 117, 132, 157, 186, 197, 208, 210, 211, 212, 213, 214, 221, 223, 247, 249, 251, 256, 263, 290, 315, 320, 333, 344, 347, 360, 367, 369, 370, 390, 391, 392, 410, 412, 425, 426, 449, 459, 460]
#               precision    recall  f1-score   support
#
#        Happy       0.80      0.94      0.87        35
#      Relaxed       0.88      0.54      0.67        13
#          Sad       1.00      1.00      1.00         3
#     Stressed       0.50      0.33      0.40         3
#
#     accuracy                           0.81        54
#    macro avg       0.79      0.70      0.73        54
# weighted avg       0.82      0.81      0.80        54
#
# Classification Report:
# Successfully processed User 6
# User 7 - Test segment windows: [7, 8, 13, 33, 36, 37, 63, 66, 79, 83, 86, 100, 103, 104, 120, 124, 129, 131, 139, 140, 162, 167, 188, 194, 208, 224, 233, 234, 242, 254, 257, 270, 276, 282, 290, 292, 294, 299, 304, 317, 334, 345, 347, 354, 365, 367, 378, 385, 387, 411, 413, 423, 434, 452, 453, 465, 470, 473, 477]
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.98      0.91        44
#      Relaxed       0.83      0.50      0.62        10
#          Sad       0.00      0.00      0.00         1
#     Stressed       0.67      0.50      0.57         4
#
#     accuracy                           0.85        59
#    macro avg       0.59      0.49      0.53        59
# weighted avg       0.83      0.85      0.83        59
#
# Classification Report:
# Successfully processed User 7
# User 8 - Test segment windows: [6, 9, 10, 32, 36, 39, 40, 52, 53, 60, 63, 70, 77, 135, 144, 147, 156, 162, 177, 201, 205, 222, 225, 226, 229, 233, 242, 243, 259, 274, 277, 280, 341, 346, 351, 359, 379, 391, 399, 417, 419, 448, 454, 456, 470, 475, 482, 484, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.89      0.96      0.93        26
#      Relaxed       1.00      0.75      0.86        12
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.91      1.00      0.95        10
#
#     accuracy                           0.92        49
#    macro avg       0.95      0.93      0.93        49
# weighted avg       0.92      0.92      0.92        49
#
# Classification Report:
# Successfully processed User 8
# User 9 - Test segment windows: [5, 6, 12, 29, 33, 34, 41, 45, 59, 62, 63, 77, 83, 84, 100, 108, 117, 122, 137, 138, 144, 187, 189, 198, 205, 216, 232, 235, 236, 241, 245, 250, 289, 295, 302, 315, 318, 323, 330, 334, 349, 353, 358, 360, 370, 376, 379, 387, 392, 394, 409, 411, 419, 428, 450, 451, 463, 467, 474, 477]
#               precision    recall  f1-score   support
#
#        Happy       0.77      0.80      0.79        30
#      Relaxed       0.75      0.82      0.78        22
#     Stressed       0.80      0.50      0.62         8
#
#     accuracy                           0.77        60
#    macro avg       0.77      0.71      0.73        60
# weighted avg       0.77      0.77      0.76        60
#
# Classification Report:
# Successfully processed User 9
# User 10 - Test segment windows: [8, 11, 12, 19, 20, 31, 39, 50, 53, 71, 72, 108, 116, 117, 127, 129, 168, 174, 194, 202, 213, 221, 222, 223, 224, 225, 231, 238, 239, 264, 267, 272, 280, 296, 311, 357, 372, 385, 393, 394, 409, 414, 417, 418, 426, 429, 430, 451, 452, 467, 468, 478, 480, 481]
#               precision    recall  f1-score   support
#
#        Happy       0.84      0.95      0.89        39
#      Relaxed       0.83      0.71      0.77         7
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.67      0.29      0.40         7
#
#     accuracy                           0.83        54
#    macro avg       0.84      0.74      0.77        54
# weighted avg       0.82      0.83      0.81        54
#
# Classification Report:
# Successfully processed User 10
# User 11 - Test segment windows: [9, 16, 25, 29, 32, 34, 35, 43, 71, 79, 80, 103, 116, 117, 128, 130, 133, 143, 146, 160, 165, 169, 175, 176, 180, 184, 185, 197, 199, 246, 271, 275, 298, 304, 312, 334, 340, 342, 372, 374, 391, 406, 407, 414, 419, 424, 426, 427, 433, 453, 457, 464, 466, 484, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.85      0.92      0.89        38
#      Relaxed       0.58      0.64      0.61        11
#          Sad       0.00      0.00      0.00         4
#     Stressed       1.00      1.00      1.00         2
#
#     accuracy                           0.80        55
#    macro avg       0.61      0.64      0.62        55
# weighted avg       0.74      0.80      0.77        55
#
# Classification Report:
# Successfully processed User 11
# User 12 - Test segment windows: [8, 9, 14, 43, 45, 54, 59, 77, 83, 84, 103, 107, 110, 126, 128, 130, 138, 147, 161, 165, 179, 182, 184, 185, 186, 194, 220, 227, 228, 231, 232, 233, 244, 246, 249, 268, 278, 304, 317, 321, 332, 379, 389, 392, 405, 407, 411, 412, 422, 429, 435, 436, 452, 453, 454, 465, 467, 468]
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.98      0.91        43
#      Relaxed       0.50      0.25      0.33         4
#     Stressed       1.00      0.64      0.78        11
#
#     accuracy                           0.86        58
#    macro avg       0.79      0.62      0.67        58
# weighted avg       0.86      0.86      0.85        58
#
# Classification Report:
# Successfully processed User 12
# User 13 - Test segment windows: [20, 42, 43, 65, 67, 71, 72, 81, 82, 91, 97, 108, 123, 157, 164, 165, 166, 189, 195, 209, 214, 229, 231, 237, 239, 248, 251, 259, 270, 272, 273, 280, 316, 320, 337, 356, 389, 392, 399, 403, 404, 407, 419, 423, 429, 437, 442, 444, 455, 466, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.77      1.00      0.87        33
#      Relaxed       1.00      0.11      0.20         9
#          Sad       0.00      0.00      0.00         1
#     Stressed       1.00      0.88      0.93         8
#
#     accuracy                           0.80        51
#    macro avg       0.69      0.50      0.50        51
# weighted avg       0.83      0.80      0.74        51
#
# Classification Report:
# Successfully processed User 13
# User 14 - Test segment windows: [6, 19, 22, 32, 36, 45, 47, 49, 61, 82, 86, 87, 108, 118, 120, 130, 132, 138, 141, 143, 152, 162, 166, 185, 192, 199, 200, 223, 225, 249, 259, 267, 281, 288, 301, 314, 326, 363, 365, 369, 375, 378, 381, 385, 399, 404, 416, 420, 421, 431, 444, 453, 456, 458, 481, 482]
#               precision    recall  f1-score   support
#
#        Happy       0.80      0.97      0.88        40
#      Relaxed       0.67      0.44      0.53         9
#          Sad       1.00      0.50      0.67         2
#     Stressed       0.00      0.00      0.00         5
#
#     accuracy                           0.79        56
#    macro avg       0.62      0.48      0.52        56
# weighted avg       0.71      0.79      0.74        56
#
# Classification Report:
# Successfully processed User 14
# User 15 - Test segment windows: [5, 8, 10, 13, 21, 28, 30, 39, 57, 61, 62, 78, 81, 85, 98, 105, 106, 107, 113, 121, 123, 138, 144, 149, 153, 163, 168, 169, 183, 210, 214, 225, 236, 241, 267, 281, 291, 308, 309, 311, 312, 321, 332, 351, 353, 357, 373, 378, 385, 388, 406, 410, 414, 438, 439, 449, 453, 454, 456, 461, 476, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.64      0.94      0.76        36
#      Relaxed       0.75      0.21      0.33        14
#          Sad       1.00      0.14      0.25         7
#     Stressed       0.75      0.60      0.67         5
#
#     accuracy                           0.66        62
#    macro avg       0.79      0.48      0.50        62
# weighted avg       0.72      0.66      0.60        62
#
# Classification Report:
# Successfully processed User 15
# User 16 - Test segment windows: [6, 9, 10, 15, 19, 22, 26, 27, 36, 53, 57, 58, 75, 83, 85, 94, 98, 103, 114, 116, 180, 190, 193, 204, 209, 215, 216, 223, 234, 245, 246, 247, 258, 273, 277, 278, 286, 292, 306, 323, 357, 364, 366, 367, 373, 377, 390, 411, 414, 417, 420, 422, 455, 461, 472, 474]
#               precision    recall  f1-score   support
#
#        Happy       0.83      0.95      0.89        42
#      Relaxed       0.50      0.33      0.40         6
#          Sad       0.00      0.00      0.00         4
#     Stressed       0.75      0.75      0.75         4
#
#     accuracy                           0.80        56
#    macro avg       0.52      0.51      0.51        56
# weighted avg       0.73      0.80      0.76        56
#
# Classification Report:
# Successfully processed User 16
# User 17 - Test segment windows: [28, 34, 46, 50, 58, 60, 61, 68, 82, 86, 87, 104, 113, 115, 126, 129, 134, 141, 145, 185, 190, 197, 200, 252, 264, 265, 266, 275, 284, 289, 296, 318, 319, 334, 372, 377, 383, 396, 400, 403, 405, 415, 416, 418, 421, 435, 439, 441, 442, 448, 462, 465, 473, 477, 478]
#               precision    recall  f1-score   support
#
#        Happy       0.72      0.96      0.83        27
#      Relaxed       0.86      0.60      0.71        10
#          Sad       0.33      0.14      0.20         7
#     Stressed       0.89      0.73      0.80        11
#
#     accuracy                           0.75        55
#    macro avg       0.70      0.61      0.63        55
# weighted avg       0.73      0.75      0.72        55
#
# Classification Report:
# Successfully processed User 17
# User 18 - Test segment windows: [6, 9, 16, 22, 27, 29, 30, 37, 53, 57, 59, 86, 112, 117, 131, 133, 138, 144, 147, 184, 189, 213, 218, 225, 234, 235, 240, 245, 253, 257, 262, 276, 277, 284, 305, 315, 319, 341, 344, 351, 354, 368, 369, 372, 377, 396, 400, 404, 405, 411, 429, 443, 465, 474, 477]
#               precision    recall  f1-score   support
#
#        Happy       0.83      0.98      0.90        45
#      Relaxed       0.50      0.14      0.22         7
#     Stressed       0.00      0.00      0.00         3
#
#     accuracy                           0.82        55
#    macro avg       0.44      0.37      0.37        55
# weighted avg       0.74      0.82      0.76        55
#
# Classification Report:
# Successfully processed User 18
# User 19 - Test segment windows: [12, 15, 16, 25, 26, 28, 29, 39, 40, 53, 56, 61, 71, 88, 97, 98, 99, 116, 120, 135, 144, 155, 158, 163, 165, 186, 187, 194, 202, 206, 207, 213, 223, 226, 230, 236, 247, 273, 284, 350, 351, 363, 373, 376, 383, 398, 405, 407, 417, 432, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.91      0.95      0.93        41
#      Relaxed       0.00      0.00      0.00         2
#     Stressed       0.75      0.75      0.75         8
#
#     accuracy                           0.88        51
#    macro avg       0.55      0.57      0.56        51
# weighted avg       0.85      0.88      0.86        51
#
# Classification Report:
# Successfully processed User 19
# User 20 - Test segment windows: [7, 11, 13, 25, 29, 32, 36, 38, 53, 84, 89, 99, 127, 136, 138, 149, 155, 162, 170, 176, 186, 196, 200, 215, 235, 248, 249, 282, 284, 293, 296, 301, 306, 311, 316, 321, 326, 341, 342, 347, 356, 359, 362, 368, 398, 414, 425, 427, 429, 435, 456, 463, 466, 468, 484, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.88      0.86      0.87        43
#      Relaxed       0.50      0.44      0.47         9
#          Sad       0.00      0.00      0.00         0
#     Stressed       0.60      0.75      0.67         4
#
#     accuracy                           0.79        56
#    macro avg       0.50      0.51      0.50        56
# weighted avg       0.80      0.79      0.79        56
#
# Classification Report:
# Successfully processed User 20
# User 21 - Test segment windows: [7, 9, 12, 25, 27, 34, 37, 51, 55, 56, 72, 78, 84, 86, 96, 98, 101, 111, 122, 131, 133, 134, 170, 171, 193, 195, 217, 221, 229, 241, 248, 249, 259, 261, 271, 274, 321, 350, 358, 367, 368, 371, 381, 382, 391, 398, 416, 418, 426, 430, 436, 446, 455, 456, 457, 468, 470]
#               precision    recall  f1-score   support
#
#        Happy       0.81      0.92      0.86        37
#      Relaxed       1.00      0.50      0.67         4
#          Sad       1.00      0.75      0.86         4
#     Stressed       0.70      0.58      0.64        12
#
#     accuracy                           0.81        57
#    macro avg       0.88      0.69      0.76        57
# weighted avg       0.81      0.81      0.80        57
#
# Classification Report:
# Successfully processed User 21
# User 22 - Test segment windows: [6, 9, 10, 15, 18, 19, 58, 60, 67, 75, 98, 106, 134, 157, 162, 164, 171, 190, 191, 198, 218, 221, 223, 225, 231, 240, 249, 259, 262, 263, 266, 301, 302, 323, 324, 329, 335, 339, 340, 342, 352, 356, 363, 381, 386, 392, 407, 413, 423, 451, 457, 479, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.71      0.97      0.82        33
#      Relaxed       0.83      0.38      0.53        13
#          Sad       0.00      0.00      0.00         2
#     Stressed       1.00      0.40      0.57         5
#
#     accuracy                           0.74        53
#    macro avg       0.64      0.44      0.48        53
# weighted avg       0.74      0.74      0.69        53
#
# Classification Report:
# Successfully processed User 22
# User 23 - Test segment windows: [12, 18, 19, 21, 22, 29, 34, 53, 72, 83, 93, 103, 105, 120, 123, 136, 148, 167, 183, 186, 198, 199, 210, 211, 212, 245, 269, 270, 275, 294, 298, 302, 333, 336, 345, 356, 361, 364, 377, 410, 412, 414, 416, 421, 460, 463, 474]
#               precision    recall  f1-score   support
#
#        Happy       0.87      0.93      0.90        28
#      Relaxed       0.75      0.75      0.75         8
#          Sad       1.00      0.57      0.73         7
#     Stressed       0.60      0.75      0.67         4
#
#     accuracy                           0.83        47
#    macro avg       0.80      0.75      0.76        47
# weighted avg       0.84      0.83      0.83        47
#
# Classification Report:
# Successfully processed User 23
# User 24 - Test segment windows: [10, 13, 14, 23, 24, 26, 27, 35, 36, 41, 44, 56, 79, 80, 81, 89, 94, 102, 117, 118, 143, 150, 154, 194, 207, 245, 257, 292, 295, 313, 314, 322, 323, 332, 333, 342, 353, 358, 360, 368, 441, 442, 445, 452, 456, 457, 464, 469, 473, 478, 487]
#               precision    recall  f1-score   support
#
#        Happy       0.95      0.97      0.96        37
#      Relaxed       1.00      1.00      1.00         2
#          Sad       1.00      1.00      1.00         2
#     Stressed       0.89      0.80      0.84        10
#
#     accuracy                           0.94        51
#    macro avg       0.96      0.94      0.95        51
# weighted avg       0.94      0.94      0.94        51
#
# Classification Report:
# Successfully processed User 24
# User 25 - Test segment windows: [7, 10, 16, 20, 23, 25, 26, 35, 38, 51, 54, 55, 69, 77, 78, 79, 90, 94, 100, 104, 107, 108, 113, 132, 137, 140, 146, 147, 156, 160, 163, 168, 175, 185, 197, 206, 232, 240, 274, 275, 286, 289, 366, 372, 407, 415, 418, 442, 446, 448, 449, 453, 463, 472]
#               precision    recall  f1-score   support
#
#        Happy       0.80      0.90      0.85        31
#      Relaxed       0.33      0.38      0.35         8
#          Sad       0.60      0.43      0.50         7
#     Stressed       0.80      0.50      0.62         8
#
#     accuracy                           0.70        54
#    macro avg       0.63      0.55      0.58        54
# weighted avg       0.70      0.70      0.70        54
#
# Classification Report:
# Successfully processed User 25
# User 26 - Test segment windows: [14, 17, 24, 28, 31, 33, 34, 39, 64, 67, 68, 88, 94, 96, 102, 106, 111, 122, 124, 173, 175, 180, 182, 183, 196, 197, 198, 207, 215, 224, 237, 261, 263, 283, 308, 312, 333, 339, 343, 351, 357, 374, 388, 392, 393, 394, 395, 411, 454, 460, 463, 465, 466, 470, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.78      0.91      0.84        34
#      Relaxed       0.67      0.29      0.40         7
#          Sad       0.50      0.67      0.57         3
#     Stressed       0.62      0.45      0.53        11
#
#     accuracy                           0.73        55
#    macro avg       0.64      0.58      0.58        55
# weighted avg       0.72      0.73      0.71        55
#
# Classification Report:
# Successfully processed User 26
# User 27 - Test segment windows: [6, 9, 17, 21, 24, 28, 29, 34, 58, 63, 64, 94, 102, 104, 118, 120, 124, 129, 131, 153, 157, 167, 172, 176, 182, 183, 184, 189, 201, 210, 216, 246, 247, 255, 285, 317, 322, 360, 362, 365, 367, 381, 382, 385, 394, 413, 416, 418, 420, 426, 451, 468, 474, 478, 479]
#               precision    recall  f1-score   support
#
#        Happy       0.76      0.91      0.83        32
#      Relaxed       0.62      0.45      0.53        11
#          Sad       0.00      0.00      0.00         2
#     Stressed       1.00      0.90      0.95        10
#
#     accuracy                           0.78        55
#    macro avg       0.60      0.57      0.58        55
# weighted avg       0.75      0.78      0.76        55
#
# Classification Report:
# Successfully processed User 27
# User 28 - Test segment windows: [9, 15, 16, 26, 31, 34, 38, 39, 50, 62, 65, 66, 83, 91, 101, 107, 109, 118, 130, 133, 144, 155, 159, 183, 187, 204, 207, 250, 256, 270, 274, 279, 294, 296, 316, 321, 335, 350, 359, 363, 364, 366, 377, 401, 425, 428, 431, 437, 461, 462, 466, 468, 470, 481, 484, 486]
#               precision    recall  f1-score   support
#
#        Happy       0.84      0.95      0.89        43
#      Relaxed       0.00      0.00      0.00         4
#          Sad       0.60      0.38      0.46         8
#     Stressed       0.50      1.00      0.67         1
#
#     accuracy                           0.80        56
#    macro avg       0.48      0.58      0.50        56
# weighted avg       0.74      0.80      0.76        56
#
# Classification Report:
# Successfully processed User 28
# User 29 - Test segment windows: [6, 16, 17, 22, 27, 28, 37, 38, 46, 55, 73, 74, 139, 141, 144, 164, 166, 169, 170, 180, 184, 206, 208, 211, 212, 217, 244, 247, 248, 254, 261, 276, 288, 315, 341, 359, 368, 369, 370, 385, 387, 390, 396, 398, 428, 433, 437, 448, 463, 465, 466, 471, 488]
#               precision    recall  f1-score   support
#
#        Happy       0.87      0.93      0.90        42
#      Relaxed       1.00      0.33      0.50         3
#     Stressed       0.57      0.50      0.53         8
#
#     accuracy                           0.83        53
#    macro avg       0.81      0.59      0.64        53
# weighted avg       0.83      0.83      0.82        53
#
# Classification Report:
# Successfully processed User 29
# User 30 - Test segment windows: [7, 12, 23, 31, 37, 40, 41, 47, 62, 69, 70, 89, 102, 104, 115, 117, 123, 130, 133, 199, 204, 214, 217, 221, 230, 231, 232, 241, 250, 253, 259, 279, 280, 319, 347, 356, 360, 373, 375, 380, 384, 395, 396, 399, 417, 436, 439, 441, 442, 449, 464, 467, 473, 477, 478]
#               precision    recall  f1-score   support
#
#        Happy       0.75      0.94      0.84        35
#      Relaxed       0.33      0.14      0.20         7
#          Sad       1.00      0.50      0.67         2
#     Stressed       0.86      0.55      0.67        11
#
#     accuracy                           0.75        55
#    macro avg       0.74      0.53      0.59        55
# weighted avg       0.73      0.75      0.71        55
#
# Classification Report:
# Successfully processed User 30
#
# Saved results to baselines/baseline_emotion_50percent_combined_train.csv

# %% [markdown]
# # xgboost/svm/random_forest

# %%
if __name__ == "__main__":
    results = []

    opportune_features = ['BVP', 'BVP_std', 'GSR', 'GSR_std', 'GSR_slope', 'Skin_temp', 'Skin_temp_std']
    model_features = ["ECG", "EMG_c", "EMG_t", "Resp", "Skin_temp"]
    change_score_features = ['BVP', 'GSR', 'Skin_temp']
    threshold = 0.5

    for user_id in range(1, 31):
        try:
            # Load data
            physio_data = load_physiological_data(
                f"../case_dataset-master/case_dataset-master/data/raw/physiological/sub{user_id}_DAQ.txt")
            va_data = load_valence_arousal_data(
                f"../case_dataset-master/case_dataset-master/data/raw/annotations/sub{user_id}_joystick.txt")

            physio_segmented, va_segmented = preprocess_data(physio_data, va_data)
            va_segmented = scale_valence_arousal(va_segmented)

            merged_data = pd.merge(
                physio_segmented.sort_values("window").reset_index(drop=True),
                va_segmented.sort_values("window").reset_index(drop=True),
                on="window", how="inner"
            )

            merged_data["emotion"] = merged_data.apply(
                lambda row: map_to_emotion_classes(row["valence"], row["arousal"]), axis=1
            )

            # Detect RuLSIF opportune moments
            change_scores = compute_rulsif_change_scores(merged_data[change_score_features].values)
            opportune_moments = label_opportune_moments(change_scores)

            if len(opportune_moments) < 5:
                print(f"Too few opportune moments for User {user_id}. Skipping...")
                continue

            opportune_data = merged_data[merged_data["window"].isin(opportune_moments)].sort_values("window")
            inopportune_data = merged_data[~merged_data["window"].isin(opportune_moments)].sort_values("window")

            # Split RuLSIF-opportune moments: 20% test, 80% train
            opportune_train_data, opportune_test_data = train_test_split(
                opportune_data, test_size=0.2, random_state=42
            )
            test_windows = sorted(opportune_test_data["window"].tolist())
            print(f"User {user_id} - Test segment windows: {test_windows}")

            # Student model detects opportune moments on:
            # [inopportune + 80% RuLSIF-opportune]
            detection_input_data = pd.concat([inopportune_data, opportune_train_data]).sort_values("window")

            student_signal_data = detection_input_data[opportune_features]
            student_change_scores = compute_rulsif_change_scores(student_signal_data[change_score_features].values)
            student_change_scores = np.append(student_change_scores, 0)  # pad to match

            student_input_array = np.column_stack([student_signal_data.values, student_change_scores])
            scaler_student = RobustScaler()
            student_input_scaled = scaler_student.fit_transform(student_input_array)

            student_model = load_student_model(user_id, model_name="random_forest")
            pred_probs = student_model.predict(student_input_scaled)
            predicted_opportune_mask = (pred_probs >= threshold)
            detected_opportune_data = detection_input_data[predicted_opportune_mask]

            if len(detected_opportune_data) < 5:
                print(f"Too few predicted opportune moments for User {user_id}. Skipping...")
                continue

            # Train emotion classifier
            X_train_emotion = detected_opportune_data[model_features]
            y_train_emotion = detected_opportune_data["emotion"]
            X_test_emotion = opportune_test_data[model_features]
            y_test_emotion = opportune_test_data["emotion"]

            print("Train class distribution:")
            print(y_train_emotion.value_counts())
            print("Test class distribution:")
            print(y_test_emotion.value_counts())

            scaler_class = RobustScaler()
            X_train_emotion_scaled = scaler_class.fit_transform(X_train_emotion)
            X_test_emotion_scaled = scaler_class.transform(X_test_emotion)

            accuracy_opportune, f1_opportune = train_and_evaluate_classifier(
                X_train_emotion_scaled, X_test_emotion_scaled, y_train_emotion, y_test_emotion
            )

            results.append({
                "User ID": user_id,
                "Accuracy": round(accuracy_opportune, 4),
                "F1 Score": round(f1_opportune, 4),
                "Opportune Moments Count": len(opportune_moments)
            })

            print(f"Successfully processed User {user_id}\n")

        except FileNotFoundError:
            print(f"Data files for User {user_id} not found. Skipping...")
            continue
        except Exception as e:
            print(f"Unexpected error processing User {user_id}: {str(e)}. Skipping...")
            continue

    results_df = pd.DataFrame(results)
    results_df.to_csv("../dump/emotion_random_forest_opportune.csv", index=False)

    print("\nFinal Results:")
    print(results_df)
# Out:
# User 1 - Test segment windows: [60, 63, 66, 67, 69, 70, 75, 80, 81, 82, 89, 92, 93, 96, 106, 107, 111, 116, 129, 133, 141, 144, 159, 162, 164, 165, 166, 175, 188, 190, 192, 194, 197, 204, 213]
# Too few predicted opportune moments for User 1. Skipping...
# User 2 - Test segment windows: [44, 66, 72, 73, 111, 112, 173, 174, 178, 183, 189, 226, 229, 235, 238, 437, 438, 439, 452, 454, 457, 462, 475, 477, 488]
# Train class distribution:
# emotion
# Happy       29
# Stressed    27
# Sad          2
# Relaxed      1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Stressed    14
# Happy        7
# Relaxed      3
# Sad          1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.75      0.43      0.55         7
#      Relaxed       0.00      0.00      0.00         3
#          Sad       0.20      1.00      0.33         1
#     Stressed       0.81      0.93      0.87        14
#
#     accuracy                           0.68        25
#    macro avg       0.44      0.59      0.44        25
# weighted avg       0.67      0.68      0.65        25
#
# Classification Report:
# Successfully processed User 2
#
# User 3 - Test segment windows: [5, 6, 9, 24, 26, 108, 111, 121, 124, 125, 135, 139, 152, 154, 156, 163, 178, 183, 195, 199, 203, 204, 225, 234, 239, 241, 244, 253, 254, 257, 258, 272, 279, 281, 285, 286, 298, 302, 307, 311, 325, 334, 341, 355, 387, 390, 394, 406, 416, 417, 419, 439, 441, 462, 466, 471, 476, 486]
# Train class distribution:
# emotion
# Stressed    4
# Relaxed     2
# Happy       1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       33
# Stressed    10
# Relaxed     10
# Sad          5
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.00      0.00      0.00        33
#      Relaxed       0.30      0.70      0.42        10
#          Sad       0.00      0.00      0.00         5
#     Stressed       0.29      1.00      0.44        10
#
#     accuracy                           0.29        58
#    macro avg       0.15      0.42      0.22        58
# weighted avg       0.10      0.29      0.15        58
#
# Classification Report:
# Successfully processed User 3
#
# User 4 - Test segment windows: [9, 12, 15, 16, 18, 19, 24, 29, 30, 31, 193, 197, 198, 202, 208, 217, 220, 383, 393, 396, 399, 403, 415, 433, 434, 436, 437, 441, 447, 455, 459, 461, 476]
# Train class distribution:
# emotion
# Happy       22
# Relaxed      8
# Stressed     5
# Sad          2
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       18
# Relaxed      7
# Stressed     5
# Sad          3
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.80      0.89      0.84        18
#      Relaxed       0.50      0.71      0.59         7
#          Sad       0.00      0.00      0.00         3
#     Stressed       1.00      0.60      0.75         5
#
#     accuracy                           0.73        33
#    macro avg       0.57      0.55      0.55        33
# weighted avg       0.69      0.73      0.70        33
#
# Classification Report:
# Successfully processed User 4
#
# User 5 - Test segment windows: [87, 90, 99, 103, 115, 117, 118, 123, 135, 138, 139, 153, 159, 161, 166, 168, 209, 214, 216, 269, 273, 278, 280, 284, 290, 291, 292, 297, 304, 307, 311, 322, 323, 330, 344, 347, 350, 360, 362, 365, 367, 374, 375, 377, 380, 419, 422, 424, 425, 430, 442, 464, 474, 478, 479]
# Train class distribution:
# emotion
# Happy       4
# Stressed    1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       37
# Stressed    14
# Relaxed      3
# Sad          1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.71      0.81      0.76        37
#      Relaxed       0.00      0.00      0.00         3
#          Sad       0.00      0.00      0.00         1
#     Stressed       0.46      0.43      0.44        14
#
#     accuracy                           0.65        55
#    macro avg       0.29      0.31      0.30        55
# weighted avg       0.60      0.65      0.62        55
#
# Classification Report:
# Successfully processed User 5
#
# User 6 - Test segment windows: [0, 4, 396, 399, 405, 409, 417, 418, 420, 426, 431, 434, 443, 460, 463, 466, 467, 470, 473, 480]
# Train class distribution:
# emotion
# Relaxed    21
# Happy      11
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy      13
# Relaxed     7
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.83      0.38      0.53        13
#      Relaxed       0.43      0.86      0.57         7
#
#     accuracy                           0.55        20
#    macro avg       0.63      0.62      0.55        20
# weighted avg       0.69      0.55      0.54        20
#
# Classification Report:
# Successfully processed User 6
#
# User 7 - Test segment windows: [0, 4, 10, 11, 18, 26, 31, 196, 198, 209, 217, 220, 271, 276, 280, 417, 418, 419, 424, 425, 426, 439, 441, 446]
# Data files for User 7 not found. Skipping...
# User 8 - Test segment windows: [226, 230, 236, 237, 238, 244, 256, 262, 268, 271, 273, 281, 291, 292, 416, 452, 453, 461, 462, 477, 482, 488]
# Train class distribution:
# emotion
# Happy       40
# Stressed    24
# Relaxed     13
# Sad          1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Stressed    10
# Happy        7
# Relaxed      5
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       1.00      1.00      1.00         7
#      Relaxed       1.00      1.00      1.00         5
#     Stressed       1.00      1.00      1.00        10
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22
#
# Classification Report:
# Successfully processed User 8
#
# User 9 - Test segment windows: [5, 6, 9, 17, 22, 24, 30, 33, 42, 45, 46, 56, 59, 60, 69, 72, 81, 83, 85, 90, 96, 107, 115, 119, 123, 124, 125, 247, 248, 266, 269, 270, 281, 282, 288, 291, 295, 299, 365, 369, 371, 390, 411, 425, 427, 429, 436, 444, 458, 461, 467, 472, 473, 474, 476, 478, 479, 482, 488]
# Train class distribution:
# emotion
# Stressed    26
# Happy       14
# Relaxed     10
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       33
# Relaxed     21
# Stressed     5
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.58      0.69        33
#      Relaxed       0.58      0.52      0.55        21
#     Stressed       0.28      1.00      0.43         5
#
#     accuracy                           0.59        59
#    macro avg       0.57      0.70      0.56        59
# weighted avg       0.71      0.59      0.62        59
#
# Classification Report:
# Successfully processed User 9
#
# User 10 - Test segment windows: [9, 15, 16, 18, 25, 30, 45, 55, 60, 68, 73, 75, 79, 82, 86, 93, 96, 100, 104, 109, 115, 126, 135, 137, 140, 143, 147, 148, 150, 156, 163, 167, 175, 258, 262, 266, 287, 288, 303, 310, 325, 337, 352]
# Train class distribution:
# emotion
# Happy      16
# Relaxed     3
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       30
# Relaxed      5
# Sad          4
# Stressed     4
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.68      0.57      0.62        30
#      Relaxed       0.17      0.60      0.26         5
#          Sad       0.00      0.00      0.00         4
#     Stressed       0.00      0.00      0.00         4
#
#     accuracy                           0.47        43
#    macro avg       0.21      0.29      0.22        43
# weighted avg       0.49      0.47      0.46        43
#
# Classification Report:
# Successfully processed User 10
#
# User 11 - Test segment windows: [9, 11, 12, 18, 19, 22, 26, 29, 30, 31, 117, 132, 136, 145, 147, 148, 150, 157, 162, 163, 312, 416, 417, 431, 438, 439, 448, 449, 456, 464]
# Train class distribution:
# emotion
# Happy       12
# Sad          6
# Stressed     4
# Relaxed      2
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy      21
# Relaxed     7
# Sad         2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.69      0.43      0.53        21
#      Relaxed       0.29      0.29      0.29         7
#          Sad       0.10      0.50      0.17         2
#
#     accuracy                           0.40        30
#    macro avg       0.36      0.40      0.33        30
# weighted avg       0.56      0.40      0.45        30
#
# Classification Report:
# Successfully processed User 11
#
# User 12 - Test segment windows: [98, 101, 104, 105, 107, 108, 113, 118, 119, 120, 213, 235, 236, 240, 246, 255, 258, 264, 274, 277, 278, 280, 281, 284, 285, 288, 308, 312, 319, 376, 377, 387, 395]
# Too few predicted opportune moments for User 12. Skipping...
# User 13 - Test segment windows: [0, 4, 10, 12, 20, 401, 438, 440, 445, 452, 459, 460, 471, 473, 477, 483, 487]
# Train class distribution:
# emotion
# Stressed    10
# Happy        6
# Relaxed      1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       10
# Stressed     5
# Relaxed      2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.80      0.80      0.80        10
#      Relaxed       0.00      0.00      0.00         2
#     Stressed       0.83      1.00      0.91         5
#
#     accuracy                           0.76        17
#    macro avg       0.54      0.60      0.57        17
# weighted avg       0.72      0.76      0.74        17
#
# Classification Report:
# Successfully processed User 13
#
# User 14 - Test segment windows: [4, 10, 12, 16, 18, 19, 30, 31, 39, 59, 63, 78, 80, 89, 102, 107, 121, 135, 136, 160, 162, 169, 175, 176, 201, 222, 229]
# Train class distribution:
# emotion
# Happy       48
# Relaxed      7
# Stressed     7
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       23
# Relaxed      3
# Stressed     1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.85      1.00      0.92        23
#      Relaxed       0.00      0.00      0.00         3
#     Stressed       0.00      0.00      0.00         1
#
#     accuracy                           0.85        27
#    macro avg       0.28      0.33      0.31        27
# weighted avg       0.73      0.85      0.78        27
#
# Classification Report:
# Successfully processed User 14
#
# User 15 - Test segment windows: [4, 10, 11, 18, 19, 26, 27, 31, 36, 40, 45, 191, 192, 200, 205, 222, 223, 226, 235, 237, 239, 242, 247, 259, 266, 277]
# Train class distribution:
# emotion
# Happy       29
# Relaxed      3
# Stressed     3
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       19
# Stressed     5
# Relaxed      2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.76      1.00      0.86        19
#      Relaxed       1.00      0.50      0.67         2
#     Stressed       0.00      0.00      0.00         5
#
#     accuracy                           0.77        26
#    macro avg       0.59      0.50      0.51        26
# weighted avg       0.63      0.77      0.68        26
#
# Classification Report:
# Successfully processed User 15
#
# User 16 - Test segment windows: [4, 44, 46, 287, 292, 295, 386, 398, 407, 409, 420, 423, 429, 435]
# Train class distribution:
# emotion
# Happy       27
# Stressed    14
# Relaxed     12
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       9
# Stressed    4
# Relaxed     1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.90      1.00      0.95         9
#      Relaxed       0.00      0.00      0.00         1
#     Stressed       1.00      1.00      1.00         4
#
#     accuracy                           0.93        14
#    macro avg       0.63      0.67      0.65        14
# weighted avg       0.86      0.93      0.89        14
#
# Classification Report:
# Successfully processed User 16
#
# User 17 - Test segment windows: [5, 7, 9, 17, 24, 25, 33, 42, 45, 46, 57, 60, 63, 73, 76, 77, 78, 82, 90, 92, 101, 104, 109, 111, 116, 118, 119, 125, 137, 139, 146, 152, 168, 175, 179, 184, 192, 193, 198, 204, 219, 296, 301, 304, 305, 309, 319, 322, 324, 327, 328, 341, 342, 345, 352, 354, 356, 357, 358, 365, 373]
# Train class distribution:
# emotion
# Happy       22
# Relaxed     17
# Sad          5
# Stressed     2
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       27
# Sad         15
# Stressed    14
# Relaxed      5
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.61      0.81      0.70        27
#      Relaxed       1.00      0.80      0.89         5
#          Sad       0.31      0.27      0.29        15
#     Stressed       0.62      0.36      0.45        14
#
#     accuracy                           0.57        61
#    macro avg       0.64      0.56      0.58        61
# weighted avg       0.57      0.57      0.56        61
#
# Classification Report:
# Successfully processed User 17
#
# User 18 - Test segment windows: [0, 111, 144, 145, 146, 168, 202, 208, 315, 318, 333, 385, 398, 400, 407, 408, 410, 411, 412, 434, 460, 481]
# Train class distribution:
# emotion
# Happy       72
# Stressed    13
# Relaxed      9
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       17
# Relaxed      3
# Stressed     2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.89      1.00      0.94        17
#      Relaxed       1.00      0.33      0.50         3
#     Stressed       1.00      1.00      1.00         2
#
#     accuracy                           0.91        22
#    macro avg       0.96      0.78      0.81        22
# weighted avg       0.92      0.91      0.89        22
#
# Classification Report:
# Successfully processed User 18
#
# User 19 - Test segment windows: [3, 5, 7, 9, 16, 25, 33, 42, 45, 46, 130, 132, 135, 138, 150, 151, 152, 153, 157, 159, 165, 168, 169, 179, 183, 189, 191, 193, 194, 201, 207, 218, 233, 239, 247, 248, 254, 260, 270, 271, 272, 279, 283, 284, 300, 301, 305, 370, 373, 377, 379, 383, 391, 400, 405, 409, 413, 414, 467, 470, 471, 473, 479, 482, 485]
# Train class distribution:
# emotion
# Happy       38
# Stressed    16
# Relaxed     10
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       57
# Stressed     7
# Relaxed      1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.96      0.91      0.94        57
#      Relaxed       0.33      1.00      0.50         1
#     Stressed       0.62      0.71      0.67         7
#
#     accuracy                           0.89        65
#    macro avg       0.64      0.88      0.70        65
# weighted avg       0.92      0.89      0.90        65
#
# Classification Report:
# Successfully processed User 19
#
# User 20 - Test segment windows: [9, 12, 15, 16, 18, 19, 24, 29, 99, 100, 136, 137, 140, 157, 162, 168, 169, 173, 189, 197, 275, 277, 280, 281, 287, 291, 314, 323, 368, 439, 445, 451, 461, 468, 470, 473]
# Train class distribution:
# emotion
# Happy       7
# Sad         5
# Relaxed     1
# Stressed    1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       20
# Relaxed      9
# Stressed     4
# Sad          3
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.56      0.95      0.70        20
#      Relaxed       0.50      0.11      0.18         9
#          Sad       0.00      0.00      0.00         3
#     Stressed       0.00      0.00      0.00         4
#
#     accuracy                           0.56        36
#    macro avg       0.26      0.27      0.22        36
# weighted avg       0.44      0.56      0.44        36
#
# Classification Report:
# Successfully processed User 20
#
# User 21 - Test segment windows: [81, 186, 224, 226, 294, 304, 310, 315, 322, 326, 329, 331, 335, 348, 356, 360, 362, 367, 371, 392, 393, 414, 429, 434, 476]
# Train class distribution:
# emotion
# Stressed    8
# Happy       6
# Sad         1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       18
# Stressed     3
# Relaxed      2
# Sad          2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       1.00      0.33      0.50        18
#      Relaxed       0.00      0.00      0.00         2
#          Sad       0.00      0.00      0.00         2
#     Stressed       0.16      1.00      0.27         3
#
#     accuracy                           0.36        25
#    macro avg       0.29      0.33      0.19        25
# weighted avg       0.74      0.36      0.39        25
#
# Classification Report:
# Successfully processed User 21
#
# User 22 - Test segment windows: [203, 211, 221, 222, 223, 229, 241, 247, 253, 256, 267, 275, 398, 400, 402, 408, 409, 410, 411, 414, 426, 488]
# Too few predicted opportune moments for User 22. Skipping...
# User 23 - Test segment windows: [0, 5, 9, 12, 16, 38, 44, 61, 65, 74, 310, 456, 460]
# Train class distribution:
# emotion
# Happy       27
# Stressed    17
# Sad          8
# Relaxed      7
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       4
# Relaxed     4
# Stressed    3
# Sad         2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.67      1.00      0.80         4
#      Relaxed       1.00      0.50      0.67         4
#          Sad       1.00      1.00      1.00         2
#     Stressed       1.00      1.00      1.00         3
#
#     accuracy                           0.85        13
#    macro avg       0.92      0.88      0.87        13
# weighted avg       0.90      0.85      0.84        13
#
# Classification Report:
# Successfully processed User 23
#
# User 24 - Test segment windows: [9, 12, 18, 19, 26, 29, 30, 31, 36, 45, 55, 56, 64, 68, 69, 73, 76, 78, 82, 104, 108, 110, 118, 197, 198, 201, 202, 211, 213, 215]
# Too few predicted opportune moments for User 24. Skipping...
# User 25 - Test segment windows: [63, 66, 72, 73, 76, 80, 83, 84, 85, 90, 99, 131, 132, 140, 143, 152, 154, 157, 158, 160, 161, 174, 366, 369, 426, 434, 435, 439, 444, 445, 448]
# Train class distribution:
# emotion
# Happy       16
# Stressed    13
# Relaxed      4
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       17
# Stressed    10
# Sad          3
# Relaxed      1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.71      0.77        17
#      Relaxed       0.50      1.00      0.67         1
#          Sad       0.00      0.00      0.00         3
#     Stressed       0.67      1.00      0.80        10
#
#     accuracy                           0.74        31
#    macro avg       0.51      0.68      0.56        31
# weighted avg       0.70      0.74      0.70        31
#
# Classification Report:
# Successfully processed User 25
#
# User 26 - Test segment windows: [103, 104, 107, 120, 122, 123, 128, 131, 146, 149, 150, 167, 172, 173, 188, 194, 199, 201, 211, 212, 234, 236, 242, 247, 255, 263, 266, 267, 271, 275, 278, 287, 290, 293, 298, 300, 302, 305, 309, 316, 320, 325, 327, 334, 339, 341, 345, 349, 351, 359, 361, 368, 374, 384, 385, 396, 420, 426, 429]
# Too few predicted opportune moments for User 26. Skipping...
# User 27 - Test segment windows: [9, 15, 16, 18, 30, 45, 55, 56, 60, 65, 66, 67, 68, 69, 75, 76, 78, 79, 82, 84, 93, 95, 104, 115, 124, 125, 128, 132, 147, 149, 161, 163, 165, 171, 177, 178, 184, 188, 191, 196, 201]
# Train class distribution:
# emotion
# Happy       19
# Stressed    12
# Relaxed      5
# Sad          1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       16
# Relaxed     13
# Stressed     9
# Sad          3
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.43      0.56      0.49        16
#      Relaxed       0.33      0.31      0.32        13
#          Sad       1.00      0.33      0.50         3
#     Stressed       1.00      0.78      0.88         9
#
#     accuracy                           0.51        41
#    macro avg       0.69      0.50      0.55        41
# weighted avg       0.57      0.51      0.52        41
#
# Classification Report:
# Successfully processed User 27
#
# User 28 - Test segment windows: [243, 272, 283, 332, 375, 441, 444, 445, 448, 459, 461, 471]
# Train class distribution:
# emotion
# Happy       34
# Sad         12
# Stressed     6
# Relaxed      4
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       9
# Stressed    1
# Sad         1
# Relaxed     1
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.90      1.00      0.95         9
#      Relaxed       1.00      1.00      1.00         1
#          Sad       1.00      1.00      1.00         1
#     Stressed       0.00      0.00      0.00         1
#
#     accuracy                           0.92        12
#    macro avg       0.72      0.75      0.74        12
# weighted avg       0.84      0.92      0.88        12
#
# Classification Report:
# Successfully processed User 28
#
# User 29 - Test segment windows: [9, 15, 16, 18, 25, 30, 45, 55, 66, 67, 73, 75, 79, 93, 96, 98, 104, 108, 111, 112, 117, 118, 338, 342, 349, 352, 353, 356, 361, 370, 431, 433, 444, 448, 449, 454, 456, 458, 462, 464, 471, 473, 479, 487]
# Train class distribution:
# emotion
# Happy       9
# Stressed    3
# Relaxed     1
# Name: count, dtype: int64
# Test class distribution:
# emotion
# Happy       39
# Stressed     3
# Relaxed      2
# Name: count, dtype: int64
#               precision    recall  f1-score   support
#
#        Happy       0.86      0.79      0.83        39
#      Relaxed       0.00      0.00      0.00         2
#     Stressed       0.00      0.00      0.00         3
#
#     accuracy                           0.70        44
#    macro avg       0.29      0.26      0.28        44
# weighted avg       0.76      0.70      0.73        44
#
# Classification Report:
# Successfully processed User 29
#
# User 30 - Test segment windows: [40, 44, 45, 50, 53, 54, 59, 60, 65, 69, 81, 82, 103, 104, 111, 113, 118, 126, 138, 160, 162, 164, 166, 169, 170, 176, 193, 194, 243, 278, 287, 288, 310, 311, 315, 316, 323, 329, 333, 336, 337, 347, 350, 353, 357, 358, 371, 374, 381, 383, 389, 391, 393]
# Too few predicted opportune moments for User 30. Skipping...
#
# Final Results:
#     User ID  Accuracy  F1 Score  Opportune Moments Count
# 0         2    0.6800    0.6514                      125
# 1         3    0.2931    0.1498                      289
# 2         4    0.7273    0.6977                      163
# 3         5    0.6545    0.6241                      275
# 4         6    0.5500    0.5421                      100
# 5         8    1.0000    1.0000                      107
# 6         9    0.5932    0.6190                      291
# 7        10    0.4651    0.4616                      212
# 8        11    0.4000    0.4484                      147
# 9        13    0.7647    0.7380                       85
# 10       14    0.8519    0.7837                      135
# 11       15    0.7692    0.6824                      130
# 12       16    0.9286    0.8947                       69
# 13       17    0.5738    0.5566                      303
# 14       18    0.9091    0.8889                      108
# 15       19    0.8923    0.9011                      321
# 16       20    0.5556    0.4364                      176
# 17       21    0.3600    0.3927                      121
# 18       23    0.8462    0.8359                       65
# 19       25    0.7419    0.7041                      151
# 20       27    0.5122    0.5200                      201
# 21       28    0.9167    0.8772                       57
# 22       29    0.7045    0.7327                      216
